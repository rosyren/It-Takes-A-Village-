# %% [markdown]
# # Imports and Installs

# %%
# !pip install selenium
# !pip install requests
# !pip install BeautifulSoup4
# !pip install pandas
# !pip install lxml
# !pip install bs4
# !pip install html5lib
# Out:
# Requirement already satisfied: selenium in c:\users\laure\appdata\local\programs\python\python39\lib\site-packages (3.141.0)
# Requirement already satisfied: urllib3 in c:\users\laure\appdata\local\programs\python\python39\lib\site-packages (from selenium) (1.26.3)
# Requirement already satisfied: requests in c:\users\laure\appdata\local\programs\python\python39\lib\site-packages (2.25.1)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\laure\appdata\local\programs\python\python39\lib\site-packages (from requests) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\laure\appdata\local\programs\python\python39\lib\site-packages (from requests) (1.26.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\laure\appdata\local\programs\python\python39\lib\site-packages (from requests) (2020.12.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\laure\appdata\local\programs\python\python39\lib\site-packages (from requests) (4.0.0)
# Requirement already satisfied: BeautifulSoup4 in c:\users\laure\appdata\local\programs\python\python39\lib\site-packages (4.9.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\laure\appdata\local\programs\python\python39\lib\site-packages (from BeautifulSoup4) (2.2)
# Requirement already satisfied: pandas in c:\users\laure\appdata\local\programs\python\python39\lib\site-packages (1.2.2)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\laure\appdata\local\programs\python\python39\lib\site-packages (from pandas) (1.20.1)
# Requirement already satisfied: pytz>=2017.3 in c:\users\laure\appdata\local\programs\python\python39\lib\site-packages (from pandas) (2021.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\laure\appdata\local\programs\python\python39\lib\site-packages (from pandas) (2.8.1)
# Requirement already satisfied: six>=1.5 in c:\users\laure\appdata\local\programs\python\python39\lib\site-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)
# Requirement already satisfied: lxml in c:\users\laure\appdata\local\programs\python\python39\lib\site-packages (4.6.2)
# Requirement already satisfied: bs4 in c:\users\laure\appdata\local\programs\python\python39\lib\site-packages (0.0.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\laure\appdata\local\programs\python\python39\lib\site-packages (from bs4) (4.9.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\laure\appdata\local\programs\python\python39\lib\site-packages (from beautifulsoup4->bs4) (2.2)
# Requirement already satisfied: html5lib in c:\users\laure\appdata\local\programs\python\python39\lib\site-packages (1.1)
# Requirement already satisfied: six>=1.9 in c:\users\laure\appdata\local\programs\python\python39\lib\site-packages (from html5lib) (1.15.0)
# Requirement already satisfied: webencodings in c:\users\laure\appdata\local\programs\python\python39\lib\site-packages (from html5lib) (0.5.1)

# %%
# !pip list
# Out:
# Package             Version
# ------------------- ----------
# altair              4.1.0
# anyio               2.1.0
# argon2-cffi         20.1.0
# astor               0.8.1
# async-generator     1.10
# attrs               20.3.0
# Babel               2.9.0
# backcall            0.2.0
# base58              2.1.0
# beautifulsoup4      4.9.3
# bleach              3.3.0
# blinker             1.4
# bs4                 0.0.1
# cachetools          4.2.1
# certifi             2020.12.5
# cffi                1.14.5
# chardet             4.0.0
# click               7.1.2
# colorama            0.4.4
# cycler              0.10.0
# decorator           4.4.2
# defusedxml          0.6.0
# entrypoints         0.3
# gitdb               4.0.5
# GitPython           3.1.13
# html5lib            1.1
# idna                2.10
# ipykernel           5.5.0
# ipython             7.20.0
# ipython-genutils    0.2.0
# ipywidgets          7.6.3
# jedi                0.18.0
# Jinja2              2.11.3
# joblib              1.0.1
# json5               0.9.5
# jsonschema          3.2.0
# jupyter-client      6.1.11
# jupyter-core        4.7.1
# jupyter-server      1.4.0
# jupyterlab          3.0.8
# jupyterlab-pygments 0.1.2
# jupyterlab-server   2.3.0
# jupyterlab-widgets  1.0.0
# kiwisolver          1.3.1
# lxml                4.6.2
# MarkupSafe          1.1.1
# matplotlib          3.3.4
# mistune             0.8.4
# nbclassic           0.2.6
# nbclient            0.5.2
# nbconvert           6.0.7
# nbformat            5.1.2
# nest-asyncio        1.5.1
# nltk                3.5
# notebook            6.2.0
# numpy               1.20.1
# packaging           20.9
# pandas              1.2.2
# pandocfilters       1.4.3
# parso               0.8.1
# pickle-mixin        1.0.2
# pickleshare         0.7.5
# Pillow              8.1.0
# pip                 21.0.1
# process-data        0.3
# prometheus-client   0.9.0
# prompt-toolkit      3.0.16
# protobuf            3.15.1
# pycparser           2.20
# pydeck              0.6.1
# Pygments            2.8.0
# pyparsing           2.4.7
# pyrsistent          0.17.3
# python-dateutil     2.8.1
# pytz                2021.1
# pywin32             300
# pywinpty            0.5.7
# pyzmq               22.0.3
# regex               2020.11.13
# requests            2.25.1
# scikit-learn        0.24.1
# scipy               1.6.1
# selenium            3.141.0
# Send2Trash          1.5.0
# setuptools          49.2.1
# six                 1.15.0
# sklearn             0.0
# smmap               3.0.5
# sniffio             1.2.0
# soupsieve           2.2
# streamlit           0.76.0
# terminado           0.9.2
# testpath            0.4.4
# threadpoolctl       2.1.0
# toml                0.10.2
# toolz               0.11.1
# tornado             6.1
# tqdm                4.57.0
# traitlets           5.0.5
# tzlocal             2.1
# urllib3             1.26.3
# validators          0.18.2
# watchdog            2.0.1
# wcwidth             0.2.5
# webencodings        0.5.1
# widgetsnbextension  3.5.1

# %%
# imports
import os
import sys
from selenium import webdriver # import web driver
from time import sleep 
import json
import requests
import bs4
from bs4 import BeautifulSoup
import pandas as pd
import time
import lxml

# Globals 
CITY='Sacramento'
INDUSTRY='healthcare'
MAX_DISTANCE_KM = '15'  # [5, 10, 15, 25, 50, 100]
BASE_URL='https://www.indeed.com/'
LEVEL='entry_level'

# %% [markdown]
# # Testing Functionality

# %%
URL = '{base_url}jobs?q={industry}&l={city}&radius={distance}&explvl={level}'.format(base_url=BASE_URL, city=CITY, industry=INDUSTRY, distance=MAX_DISTANCE_KM, level=LEVEL)

#conducting a request of the stated URL above:
page = requests.get(URL)

#specifying a desired format of “page” using the html parser - this allows python to read the various components of the page, rather than treating it as one long string.
soup = BeautifulSoup(page.text, 'html.parser')

#printing soup in a more structured tree format that makes for easier reading
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en">
#  <head>
#   <meta content="text/html;charset=utf-8" http-equiv="content-type"/>
#   <script src="//d3fw5vlhllyvee.cloudfront.net/s/ffe72ff/en_US.js" type="text/javascript">
#   </script>
#   <link href="//d3fw5vlhllyvee.cloudfront.net/s/105b986/jobsearch_all.css" rel="stylesheet" type="text/css"/>
#   <link href="https://rss.indeed.com/rss?q=healthcare&amp;l=Sacramento&amp;radius=15&amp;explvl=entry_level" rel="alternate" title="Healthcare Jobs, Employment in Sacramento, CA" type="application/rss+xml"/>
#   <link href="/m/jobs?q=healthcare&amp;l=Sacramento&amp;radius=15&amp;explvl=entry_level" media="only screen and (max-width: 640px)" rel="alternate"/>
#   <script type="text/javascript">
#    if (typeof window['closureReadyCallbacks'] == 'undefined') {
# window['closureReadyCallbacks'] = [];
# }
#
# function call_when_jsall_loaded(cb) {
# if (window['closureReady']) {
# cb();
# } else {
# window['closureReadyCallbacks'].push(cb);
# }
# }
#   </script>
#   <meta content="1" name="ppstriptst"/>
#   <script>
#    var _scriptDownloadCount = 0;
# var _retryDownload = function() {
# var script = document.createElement('script');
# var path = '//d3fw5vlhllyvee.cloudfront.net/s/8dc1c1a/jobsearch-all-compiled.js';
# script.async = false;
# script.src = path;
# script.onerror=_onMainJSBundleError;
# document.head.appendChild(script);
# };
# var _onMainJSBundleError = function() {
# try {
#
# // for failed downloads, we want to retry the download up to 5 times
# if (_scriptDownloadCount < 4) {
# _scriptDownloadCount++;
# _retryDownload();
# return;
# }
#
# // if we've exhausted all retries, send a ping to log the failure
# var img = document.createElement("img");
# var tk = "1ev2taqp33kmi002"; // tk
# img.src = "/rpc/log?a=jasxJsLoadError&tk=" + tk;
# document.head.appendChild(img);
# document.head.removeChild(img);
#
# } catch(e) {}
# }
#   </script>
#   <script crossorigin="anonymous" onerror="_onMainJSBundleError()" src="//d3fw5vlhllyvee.cloudfront.net/s/8dc1c1a/jobsearch-all-compiled.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    var searchUID = '1ev2taqp33kmi002';
# var tk = '1ev2taqp33kmi002';
#
# var loggedIn = false;
# var dcmPayload = 'jobse0;jobal0;viewj0;savej0;6927552';
# var myindeed = true;
# var userEmail = '';
# var tellFriendEmail = '';
# var globalLoginURL = 'https:\/\/www.indeed.com\/account\/login?dest=%2Fjobs%3Fq%3Dhealthcare%26l%3DSacramento%26radius%3D15%26explvl%3Dentry_level';
# var globalRegisterURL = 'https:\/\/www.indeed.com\/account\/register?dest=%2Fjobs%3Fq%3Dhealthcare%26l%3DSacramento%26radius%3D15%26explvl%3Dentry_level';
# var searchKey = 'e12c5547e8f9af29';
# var searchState = 'q=healthcare&amp;l=Sacramento&amp;radius=15';
# var searchQS = 'q=healthcare&l=Sacramento&radius=15&explvl=entry_level';
# var eventType = 'jobsearch';
# var locale = 'en_US';
# function clk(id) { var a = document.getElementById(id); var hr = a.href; var si = a.href.indexOf('&jsa='); if (si > 0) return; var jsh = hr + '&tk=1ev2taqp33kmi002&jsa=4147'; a.href = jsh; }
# function sjomd(id) { var a = document.getElementById(id); var hr = a.href; var ocs = hr.indexOf('&oc=1'); if (ocs < 0) return; var oce = ocs + 5; a.href = hr.substring(0, ocs) + hr.substring(oce); }
# function sjoc(id, sal) { var a = document.getElementById(id); a.href = a.href + '&oc=1&sal='+sal; }
# function ptk(st,p) {document.cookie = 'PTK="tk=1ev2taqp33kmi002&type=jobsearch&subtype='+st+(p?'&'+p:'')+'"; path=/';}
# function rbptk(st, c, p) { ptk(st, 'cat='+c+(p?'&p='+p:''));}
#   </script>
#   <script type="text/javascript">
#    function loadJSAsync( ) {
# for ( var i = 0; i < arguments.length; i++ ) {
# var url = arguments[i];
# (function() {
# var s = document.createElement("script"), el = document.getElementsByTagName("script")[0];
# s.async = true;
# s.src = url;
# el.parentNode.insertBefore(s, el);
# })();
# }
# }
#   </script>
#   <style type="text/css">
#    #resultsBody #pageContent #resultsCol .row .salarySnippet{padding-top:0.5rem}
#   </style>
#   <style type="text/css">
#    body.janus #resultsCol .clickcard .jobtitle a,body.janus #resultsCol .clickcard a.jobtitle{text-decoration:none}body.janus #resultsCol .clickcard:hover .jobtitle a,body.janus #resultsCol .clickcard:hover a.jobtitle{text-decoration:underline}
#   </style>
#   <style type="text/css">
#    body.janus #resultsCol .pagination{display:flex;justify-content:center;margin-right:0 !important}body.janus #resultsCol .pagination .pagination-list{display:flex;padding-left:0;list-style:none}body.janus #resultsCol .pagination .pagination-list li{margin-right:16px}body.janus #resultsCol .pagination .pagination-list li a{margin-left:0 !important;text-decoration:none;display:block}body.desktopAurora #resultsCol .pagination .pagination-list li a:focus span.pn{background-color:#e4e2e0;border:0;box-shadow:inset 0 0.125rem 0 transparent,0 0 0 0.125rem #fff,0 0 0 0.1875rem #2557a7}body.desktopAurora #resultsCol .pagination .pagination-list li a:active span.pn{background:#d9d9d9;box-shadow:inset 0 0.0625rem 0.25rem rgba(0,0,0,0.1)}body.desktopAurora #resultsCol .pagination .pagination-list li a:active:focus span.pn{border:0;box-shadow:inset 0 0.125rem 0 transparent,0 0 0 0.125rem #fff,0 0 0 0.1875rem #2557a7}body.janus #resultsCol .pagination .pagination-list li a span.pn{display:flex;justify-content:center;align-items:center;background:#ececec;color:#2d2d2d !important;font-weight:400 !important;border-radius:8px;height:40px;width:40px;font-size:1.125rem !important}body.desktopAurora #resultsCol .pagination .pagination-list li a span.pn{background-color:#e4e2e0}body.janus #resultsCol .pagination .pagination-list li a span.pn span.np{display:flex}body.janus #resultsCol .pagination .pagination-list li a span.pn:hover{background:#e3e3e3;box-shadow:inset 0 1px 4px rgba(0,0,0,0.1);border:1px #085ff7}body.desktopAurora #resultsCol .pagination .pagination-list li a span.pn:hover{background-color:#d4d2d0}body.janus #resultsCol .pagination .pagination-list li a span.pn:active:focus{background:#d9d9d9;box-shadow:inset 0 1px 4px rgba(0,0,0,0.1);border:1px #085ff7}body.janus #resultsCol .pagination .pagination-list li a span.pn:active{background:#d9d9d9;box-shadow:inset 0 1px 4px rgba(0,0,0,0.1)}body.janus #resultsCol .pagination .pagination-list li b{background:#4b4b4b;color:#fff !important;font-weight:700;border-radius:8px;height:40px;width:40px;font-size:1.125rem !important;display:flex;align-items:center;justify-content:center;margin-left:0 !important;text-decoration:none}body.desktopAurora #resultsCol .pagination .pagination-list li b{background-color:#595959}body.janus #resultsCol .pagination .pagination-list li a:focus,body.janus #resultsCol .pagination .pagination-list li b:focus{outline:0;border-radius:9px;border:1px #085ff7;box-shadow:inset 0 2px 0 transparent,0 0 0 2px #fff,0 0 0 3px #085ff7}body.desktopAurora #resultsCol .pagination .pagination-list li a:focus,body.desktopAurora #resultsCol .pagination .pagination-list li b:focus{box-shadow:inset 0 0.125rem 0 transparent,0 0 0 0.125rem #fff,0 0 0 0.1875rem #2557a7}[dir="ltr"] body.janus #resultsCol .pagination .pagination-list li:last-child{margin-right:0}[dir="rtl"] body.janus #resultsCol .pagination .pagination-list li:first-child{margin-right:0}
#   </style>
#   <style>
#    .serp-UrgentlyHiringMessage{display:-ms-flexbox;display:-webkit-flex;display:flex;-webkit-box-align:center;-ms-flex-align:center;align-items:center}.serp-UrgentlyHiringMessage-icon{margin-right:0.3125rem;height:1rem;width:1rem}.serp-UrgentlyHiringMessage-text{font-size:0.75rem;line-height:1.25rem}.serpvj-UrgentlyHiringMessage{display:-ms-flexbox;display:-webkit-flex;display:flex;-webkit-box-align:center;-ms-flex-align:center;align-items:center}.serpvj-UrgentlyHiringMessage-icon{margin-right:0.5rem;height:1.25rem;width:1.25rem}.serpvj-UrgentlyHiringMessage-text{font-size:0.875rem;line-height:1.25rem;font-weight:bold}.jasxrefreshcombotst .serpvj-UrgentlyHiringMessage-text{color:#2d2d2d}
#   </style>
#   <style type="text/css">
#    body #resultsBody #pageContent #resultsCol .row.unifiedRow .jobCardReqContainer{padding-top:1rem}body #resultsBody #pageContent #resultsCol .row.unifiedRow .jobCardReqContainer+.jobCardShelfContainer,body #resultsBody #pageContent #resultsCol .row.unifiedRow .jobCardReqContainer+.summary,body #resultsBody #pageContent #resultsCol .row.unifiedRow .jobCardReqContainer+.jobsearch-SerpJobCard-footer .result-link-bar-container{padding-top:1rem}body #resultsBody #pageContent #resultsCol .row.unifiedRow .jobCardReqHeader{font-size:1rem;line-height:1.5rem;font-weight:700;letter-spacing:0;color:#2d2d2d}body #resultsBody #pageContent #resultsCol .row.unifiedRow .jobCardReqHeader+.jobCardReqList .jobCardReqItem:first-of-type{padding-top:0.5rem}body #resultsBody #pageContent #resultsCol .row.unifiedRow .jobCardReqItem:first-of-type{padding-top:0}body #resultsBody #pageContent #resultsCol .row.unifiedRow .jobCardReqItem,body #resultsBody #pageContent #resultsCol .row.unifiedRow .jobCardReqMore{font-size:0.875rem;line-height:1.25rem;padding-top:0.5rem;color:#2d2d2d}body #resultsBody #pageContent #resultsCol .row.unifiedRow .jobCardReqAddtlString{padding-left:0.75rem}
#   </style>
#   <style>
#    [dir] body .icl-Button,[dir] body .icl-Button--primary,[dir] .jasxrefreshcombotst .mosaic .icl-Button{border-radius:0.5rem}[dir] body .icl-Button--primary{background-color:#085ff7;border-color:transparent;color:#fff}[dir] body .icl-Button--primary:hover{background:#0750cf;border-color:transparent;box-shadow:inset 0 0.0625rem 0.25rem rgba(0,0,0,0.2);color:#fff;cursor:pointer}[dir] body .icl-Button--primary:focus{background:#0750cf;border-color:transparent;box-shadow:inset 0 0.0625rem 0.25rem rgba(0,0,0,0.2),0 0 0 2px #fff,0 0 0 3px #085ff7;color:#fff;outline:none}[dir] body .icl-Button--primary:active{background:#0648bc;border-color:transparent;box-shadow:inset 0 0.0625rem 0.25rem rgba(0,0,0,0.2);color:#fff}[dir] body .icl-Button--primary:hover:focus{outline:none;box-shadow:inset 0 0.0625rem 0.25rem rgba(0,0,0,0.2),0 0 0 2px #fff,0 0 0 3px #085ff7}[dir] body .icl-Button--primary:hover:focus:active{box-shadow:none;outline:none}[dir] body .icl-Button--secondary{background-color:#ececec !important;border-color:transparent !important;color:#2d2d2d !important;border:0 !important;padding:0.5rem 1.25rem !important}[dir] body .icl-Button--secondary:hover{background:#e3e3e3 !important;border-color:transparent !important;box-shadow:inset 0 0.0625rem 0.25rem rgba(0,0,0,0.1) !important;color:#2d2d2d !important;cursor:pointer}[dir] body .icl-Button--secondary:focus{background:#e3e3e3 !important;border-color:transparent !important;box-shadow:inset 0 0.0625rem 0.25rem rgba(0,0,0,0.1),0 0 0 2px #fff,0 0 0 3px #085ff7 !important;color:#2d2d2d !important;outline:none !important}[dir] body .icl-Button--secondary:active{background:#d9d9d9 !important;border-color:transparent !important;box-shadow:inset 0 0.0625rem 0.25rem rgba(0,0,0,0.1) !important;color:#2d2d2d !important}[dir] body .icl-Button--secondary:hover:focus{outline:none !important;box-shadow:inset 0 0.0625rem 0.25rem rgba(0,0,0,0.1),0 0 0 2px #fff,0 0 0 3px #085ff7 !important}[dir] body .icl-Button--secondary:hover:focus:active{box-shadow:none !important;outline:none !important}body.janus table .footerCta.greyBar [dir] .icl-Button.cta_button.blue{border-radius:0.5rem !important;background-color:#085ff7 !important;border-color:transparent !important;color:#fff !important}body.janus table .footerCta.greyBar [dir] .icl-Button.cta_button.blue:hover{background:#0750cf !important;border-color:transparent !important;box-shadow:inset 0 0.0625rem 0.25rem rgba(0,0,0,0.2) !important;color:#fff !important;cursor:pointer}body.janus table .footerCta.greyBar [dir] .icl-Button.cta_button.blue:focus{background:#0750cf !important;border-color:transparent !important;box-shadow:inset 0 0.0625rem 0.25rem rgba(0,0,0,0.2),0 0 0 2px #fff,0 0 0 3px #085ff7 !important;color:#fff !important;outline:none !important}body.janus table .footerCta.greyBar [dir] .icl-Button.cta_button.blue:active{background:#0648bc !important;border-color:transparent !important;box-shadow:inset 0 0.0625rem 0.25rem rgba(0,0,0,0.2) !important;color:#fff !important}body.janus table .footerCta.greyBar [dir] .icl-Button.cta_button.blue:hover:focus{outline:none !important;box-shadow:inset 0 0.0625rem 0.25rem rgba(0,0,0,0.2),0 0 0 2px #fff,0 0 0 3px #085ff7 !important}body.janus table .footerCta.greyBar [dir] .icl-Button.cta_button.blue:hover:focus:active{box-shadow:none !important;outline:none !important}#hiring-event-container-iframe{border-radius:0.5rem}.jasxrefreshcombotst .popover-button-redesign{border-radius:0.5rem !important;background-color:#085ff7 !important;border-color:transparent !important;color:#fff !important}.jasxrefreshcombotst .popover-button-redesign:hover{background:#0750cf !important;border-color:transparent !important;box-shadow:inset 0 0.0625rem 0.25rem rgba(0,0,0,0.2) !important;color:#fff !important;cursor:pointer}.jasxrefreshcombotst .popover-button-redesign:focus{background:#0750cf !important;border-color:transparent !important;box-shadow:inset 0 0.0625rem 0.25rem rgba(0,0,0,0.2),0 0 0 2px #fff,0 0 0 3px #085ff7 ! ...
#   </style>
#   <style>
#    .jobsearch-ThirdPartyApplyCreateAccountModal{font-style:normal;font-weight:normal;font-size:1rem;line-height:1.5}.jobsearch-ThirdPartyApplyCreateAccountModal-container{display:flex}.jobsearch-ThirdPartyApplyCreateAccountModal-textCol{width:306px}.jobsearch-ThirdPartyApplyCreateAccountModal-imageCol{width:305px;margin-left:20px;text-align:right}.jobsearch-ThirdPartyApplyCreateAccountModal-button{margin-top:8px !important;border-radius:8px !important;font-weight:bold;line-height:1.125rem;text-align:center}.jobsearch-ThirdPartyApplyCreateAccountModal .icl-Modal{width:700px;height:294px}.jobsearch-ThirdPartyApplyCreateAccountModal .icl-Modal-header{font-weight:bold;font-size:1.5rem;line-height:1.875rem}.jobsearch-ThirdPartyApplyCreateAccountModal .icl-Modal-guts{padding-left:32px !important}#jobsearch-ThirdPartyApplyCreateAccountModal-createAccountButton{border-radius:8px !important;font-size:1rem !important;padding-top:0.75rem !important;padding-bottom:0.75rem !important}.jobsearch-SuccessfullySignedInModal{font-style:normal;font-weight:normal;font-size:1rem;line-height:1.5rem}.jobsearch-SuccessfullySignedInModal-container{display:flex}.jobsearch-SuccessfullySignedInModal-textCol{width:306px}.jobsearch-SuccessfullySignedInModal-imageContainer{width:305px;margin-left:20px;text-align:right;margin-top:-20}.jobsearch-SuccessfullySignedInModal-button{margin-top:32px !important;border-radius:8px !important;font-weight:bold;line-height:1.125rem;text-align:center}.jobsearch-SuccessfullySignedInModal-redirectText{margin-top:16px !important;text-align:center}.jobsearch-SuccessfullySignedInModal .icl-Modal{width:700px;height:274px}.jobsearch-SuccessfullySignedInModal .icl-Modal-header{font-weight:bold;font-size:1.5rem !important;line-height:1.875rem;margin-top:14px}.jobsearch-SuccessfullySignedInModal .icl-Modal-guts{padding-left:32px !important}.jobsearch-SuccessfullySignedInModal .icl-Modal-body{margin-bottom:0 !important}#jobsearch-SuccessfullySignedInModal-continueButton{border-radius:8px !important;font-size:1rem !important;padding-top:0.75rem !important;padding-bottom:0.75rem !important}
#   </style>
#   <link href="//d3fw5vlhllyvee.cloudfront.net/s/712a27b/Grid.css" rel="stylesheet" type="text/css">
#    <link href="//d3fw5vlhllyvee.cloudfront.net/s/cd7ca1d/Icon.css" rel="stylesheet" type="text/css">
#     <link href="//d3fw5vlhllyvee.cloudfront.net/s/56b285a/jasx-serp.css" rel="stylesheet" type="text/css">
#      <link href="//d3fw5vlhllyvee.cloudfront.net/s/c243447/salarylegaldisclaimer.css" rel="stylesheet" type="text/css"/>
#      <link href="//d3fw5vlhllyvee.cloudfront.net/s/05fda91/salaryestimates.css" rel="stylesheet" type="text/css"/>
#      <style type="text/css">
#       #resultsBody { padding: 0; border-spacing: 0; border: 0; }
#
# #resultsCol { padding-top: 0; }
# .searchCount { margin-top: 6px; }
# .showing { padding-top: 9px; padding-bottom: 9px; }
#
# .brdr { height: 1px; overflow: hidden; background-color: #ccc; }
#
# /* Tall window sizes */
# @media only screen and (min-height:780px){
# .showing { padding-bottom: 0; }
# }
#
# /* Wide window sizes */
# @media only screen and (min-width:1125px){
# .brdr  { margin-left: 12px; margin-right: 12px; }
# }
#
# a,a:link,.link,.btn,.btn:hover{text-decoration:none}a:hover,.link:hover{text-decoration:underline}.dya-container a{text-decoration:underline !important}
#      </style>
#      <style>
#       body.janus table #resultsCol .related_searches .rightBorder:after{content:none}body.janus #resultsCol .related_searches>div:first-child{margin-bottom:1rem}.related_searches>div:first-child>b:not([class]){color:#2d2d2d;display:block;font-size:1.125rem;font-weight:bold;letter-spacing:-0.06px;line-height:1.5rem;margin:0 0 1rem}.related_searches>div:first-child li{margin-bottom:0.5rem}.related_searches>div:first-child a{background-color:#ececec;background-image:url("data:image/svg+xml;charset=utf8,%3Csvg width='16' height='16' viewBox='0 0 16 16' fill='none' xmlns='http://www.w3.org/2000/svg'%3E%3Cpath fill-rule='evenodd' clip-rule='evenodd' d='M10.3333 9.33333H9.80667L9.62 9.15333C10.2733 8.39333 10.6667 7.40667 10.6667 6.33333C10.6667 3.94 8.72667 2 6.33333 2C3.94 2 2 3.94 2 6.33333C2 8.72667 3.94 10.6667 6.33333 10.6667C7.40667 10.6667 8.39333 10.2733 9.15333 9.62L9.33333 9.80667V10.3333L12.6667 13.66L13.66 12.6667L10.3333 9.33333ZM6.33337 9.33334C4.67337 9.33334 3.33337 7.99334 3.33337 6.33334C3.33337 4.67334 4.67337 3.33334 6.33337 3.33334C7.99337 3.33334 9.33337 4.67334 9.33337 6.33334C9.33337 7.99334 7.99337 9.33334 6.33337 9.33334Z' fill='%232D2D2D'/%3E%3C/svg%3E");background-position:0.5rem 50%;background-repeat:no-repeat;border-radius:0.5rem;display:inline-block;font-size:0.875rem;font-weight:bold;line-height:1.25rem;min-height:36px;padding:0.5rem 0.75rem 0.5rem 2rem}.related_searches>div:first-child a:hover{background-color:#e3e3e3;box-shadow:inset 0 1px 0.25rem rgba(0,0,0,0.1);cursor:pointer;text-decoration:none}.related_searches>div:first-child a:focus{outline:0;box-shadow:inset 0 1px 0.25rem rgba(0,0,0,0.2),0 0 0 2px #fff,0 0 0 3px #085ff7}.related_searches>div:first-child a:active{background-color:#d9d9d9;box-shadow:inset 0 1px 0.25rem rgba(0,0,0,0.1);color:#2d2d2d}#resultsCol .related_searches .related_searches_list ul a{color:#2d2d2d !important}body.janus #resultsCol .related_searches a{color:#2d2d2d !important}[dir] body.janus .relatedQuerySpacing table td a{color:#2d2d2d !important}body.janus #resultsCol .related_searches ul .rightBorder{margin-right:0.5rem}body.janus #resultsCol .related_searches ul .rightBorder:last-of-type{margin-right:0}body.janus table #resultsCol .related_searches{padding:1.5rem 0 0}.related_searches_list+style+.related_searches_list{border-top:1px solid #ececec;padding-top:1rem;margin-top:1rem}div.related_searches>div:first-child{font-size:0}div.related_searches>div:first-child>a{margin-right:0.5rem;margin-bottom:0.5rem}div.related_searches>div:first-child>a:last-of-type{margin-right:0}.relatedQuerySpacing b{color:#2d2d2d;display:block;font-size:1.125rem;font-weight:bold;letter-spacing:-0.06px;line-height:1.5rem;margin:0 0 1rem}.relatedQuerySpacing ul.relatedQueries-listView-pageLast{padding:0;column-count:initial;overflow:visible}.relatedQuerySpacing ul.relatedQueries-listView-pageLast a[href]{background-color:#ececec;background-image:url("data:image/svg+xml;charset=utf8,%3Csvg width='16' height='16' viewBox='0 0 16 16' fill='none' xmlns='http://www.w3.org/2000/svg'%3E%3Cpath fill-rule='evenodd' clip-rule='evenodd' d='M10.3333 9.33333H9.80667L9.62 9.15333C10.2733 8.39333 10.6667 7.40667 10.6667 6.33333C10.6667 3.94 8.72667 2 6.33333 2C3.94 2 2 3.94 2 6.33333C2 8.72667 3.94 10.6667 6.33333 10.6667C7.40667 10.6667 8.39333 10.2733 9.15333 9.62L9.33333 9.80667V10.3333L12.6667 13.66L13.66 12.6667L10.3333 9.33333ZM6.33337 9.33334C4.67337 9.33334 3.33337 7.99334 3.33337 6.33334C3.33337 4.67334 4.67337 3.33334 6.33337 3.33334C7.99337 3.33334 9.33337 4.67334 9.33337 6.33334C9.33337 7.99334 7.99337 9.33334 6.33337 9.33334Z' fill='%232D2D2D'/%3E%3C/svg%3E");background-position:0.5rem 50%;background-repeat:no-repeat;border-radius:0.5rem;display:inline-block;font-size:0.875rem;font-weight:bold;line-height:1.25rem;min-height:36px;padding:0.5rem 0.75rem 0.5rem 2rem;color:#2d2d2d !important}.relatedQuerySpacing ul.relatedQueries-listView-pageLast a[href]:hover{background-color:#e3e3e3;box-shadow:i ...
#      </style>
#      <style>
#       .inwrap .popover-input-locationtst{height:2.625rem;border-radius:0.1875rem;border-style:solid;border-width:0.125rem;padding-left:0.375rem;margin-top:0.3125rem;font-size:0.875rem}body .popover-form-locationtst .popover-input-locationtst[disabled],body .popover-form-locationtst .popover-input-locationtst[disabled]:active,body .popover-form-locationtst .popover-input-locationtst[disabled]:focus{border-color:#d6d6d6;color:#909090;box-shadow:none}:root .icl-TextInput-control,:root .popover-input-locationtst{color:#2d2d2d;border-color:#d4d2d0;color:#2d2d2d !important}:root .icl-TextInput-control:active,:root .icl-TextInput-control:focus,:root .popover-input-locationtst:active,:root .popover-input-locationtst:focus{border-color:#2557a7 !important}:root .icl-Button--secondary{border-color:#2557a7 !important;color:#2557a7 !important;transition:background-color 180ms ease-out,border-color 180ms ease-out}:root .icl-Button--secondary:active,:root .icl-Button--secondary:focus,:root .icl-Button--secondary:hover{background-color:unset !important}:root .icl-Button--secondary:active,:root .icl-Button--secondary:hover{border-color:#0d2d5e !important;color:#0d2d5e !important}:root .icl-Button--secondary:focus{box-shadow:inset 0 0.0625rem 0.25rem rgba(0,0,0,0.1),0 0 0 0.125rem #fff,0 0 0 0.1875rem #2557a7;border-color:#2557a7 !important}:root #cmp-root #cmp-footer input[type='submit'],:root .icl-Button--tertiary{border-color:#d4d2d0 !important;color:#2557a7 !important;transition:background-color 180ms ease-out,border-color 180ms ease-out}:root #cmp-root #cmp-footer input[type='submit']:active,:root #cmp-root #cmp-footer input[type='submit']:focus,:root #cmp-root #cmp-footer input[type='submit']:hover,:root .icl-Button--tertiary:active,:root .icl-Button--tertiary:focus,:root .icl-Button--tertiary:hover{background-color:unset !important}:root #cmp-root #cmp-footer input[type='submit']:active,:root #cmp-root #cmp-footer input[type='submit']:hover,:root .icl-Button--tertiary:active,:root .icl-Button--tertiary:hover{border-color:#949494 !important;color:#0d2d5e !important}:root #cmp-root #cmp-footer input[type='submit']:focus,:root .icl-Button--tertiary:focus{box-shadow:inset 0 0.0625rem 0.25rem rgba(0,0,0,0.1),0 0 0 0.125rem #fff,0 0 0 0.1875rem #2557a7}:root .icl-Icon--blue{fill:#2557a7}:root .icl-Card--hasBorder,:root .jobsearch-JobComponent-bottomDivider{border-color:#f3f2f1}:root .jamodal-gdpr,:root .mosaic-provider-reportcontent .report-content-legal-tos{color:#767676}:root #jamodal-email{color:#2d2d2d !important}:root #jamodal-email:active,:root #jamodal-email:focus{border-color:#2557a7 !important}:root .jamodal-heading{color:#2d2d2d}:root .jamodal-heading-container{border-bottom:0.125rem solid #faf9f8}:root #cmp-root #cmp-discovery a,:root #cmp-root #cmp-page .cmp-breadcrumb li a,:root #cmp-root .sal-job-openings-link,:root .femp_links,:root .femp_links div,:root a:not(.gnav-SkipNavLink):not(.icl-Button),:root a:not(.gnav-SkipNavLink):not(.icl-Button):link,:root body.janus #resultsBody #pageContent #resultsCol .result .sign-in-container .ws_content a{color:#2557a7 !important}:root .ws_content{border:none;background-color:#faf9f8 !important}:root .jobsearch-ViewJobLayout .icl-Button--whatWhere,:root body.janus table #jobsearch.jsf .inwrapBorder .input_submit{background-color:#2557a7 !important;border-color:#2557a7 !important;transition:background-color 200ms ease-out,border-color 200ms ease-out;font-size:0.875rem;font-weight:600}:root .jobsearch-ViewJobLayout .icl-Button--whatWhere:hover,:root body.janus table #jobsearch.jsf .inwrapBorder .input_submit:hover{background-color:#0d2d5e !important;border-color:#0d2d5e !important}:root .jobsearch-ViewJobLayout .icl-Button--whatWhere:active,:root body.janus table #jobsearch.jsf .inwrapBorder .input_submit:active{background-color:#0d2d5e !important;color:#fff !important;border-color:#0d2d5e !important}:root .jobsearch-ViewJobLayout .icl-Button--whatWhere:focus,:root body.janus table #jobsearch.j ...
#      </style>
#      <style>
#       .related_searches .relatedQueries-listItem-pageFirst a{background:url("data:image/svg+xml,%3Csvg width='18' height='18' viewBox='0 0 18 18' fill='none' xmlns='http://www.w3.org/2000/svg'%3E%3Cpath fill-rule='evenodd' clip-rule='evenodd' d='M11.9683 11.0486C13.4807 9.08769 13.3381 6.26167 11.5404 4.46398C9.58779 2.51136 6.42197 2.51136 4.46935 4.46398C2.51673 6.4166 2.51673 9.58242 4.46935 11.535C6.26597 13.3317 9.08968 13.4752 11.0504 11.9657C11.0581 11.9746 11.0663 11.9833 11.0747 11.9917L13.9348 14.8518C14.13 15.047 14.4466 15.047 14.6419 14.8518L14.854 14.6396C15.0493 14.4444 15.0493 14.1278 14.854 13.9325L11.994 11.0725C11.9856 11.0642 11.9771 11.0562 11.9683 11.0486ZM10.6212 5.38322C12.0661 6.82816 12.0661 9.17087 10.6212 10.6158C9.17624 12.0607 6.83353 12.0607 5.38859 10.6158C3.94365 9.17087 3.94365 6.82816 5.38859 5.38322C6.83353 3.93828 9.17624 3.93828 10.6212 5.38322Z' fill='%232D2D2D'/%3E%3C/svg%3E%0A") no-repeat !important;background-size:18px !important;background-position:8px 50% !important}body.janus .job-reaction .job-reaction-kebab{background:url("data:image/svg+xml,%3Csvg width='24' height='24' viewBox='0 0 24 24' fill='none' xmlns='http://www.w3.org/2000/svg'%3E%3Cpath d='M12 7C13.1 7 14 6.1 14 5C14 3.9 13.1 3 12 3C10.9 3 10 3.9 10 5C10 6.1 10.9 7 12 7ZM12 10C10.9 10 10 10.9 10 12C10 13.1 10.9 14 12 14C13.1 14 14 13.1 14 12C14 10.9 13.1 10 12 10ZM12 17C10.9 17 10 17.9 10 19C10 20.1 10.9 21 12 21C13.1 21 14 20.1 14 19C14 17.9 13.1 17 12 17Z' fill='%23767676'/%3E%3C/svg%3E%0A") no-repeat !important;background-size:24px !important;background-position:50% !important}.job-reaction-save svg{background:url("data:image/svg+xml,%3Csvg width='24' height='24' viewBox='0 0 24 24' fill='none' xmlns='http://www.w3.org/2000/svg'%3E%3Cpath fill-rule='evenodd' clip-rule='evenodd' d='M10.5766 6.99526C10.0636 6.48227 9.57017 5.99808 9.01069 5.62604C8.46832 5.26538 7.97822 5.09021 7.5 5.09021C6.79435 5.09021 5.98045 5.27268 5.34087 5.72415C4.78259 6.11822 4.20245 6.82046 4.00092 8.2167C4.02709 10.0041 4.61435 11.2599 5.97077 12.7896C6.98048 13.9283 8.27849 15.0775 9.97941 16.5833C10.5978 17.1308 11.2695 17.7255 12 18.3839C12.7305 17.7255 13.4022 17.1308 14.0206 16.5833C15.7215 15.0775 17.0195 13.9283 18.0292 12.7896C19.3856 11.2599 19.9729 10.0041 19.9991 8.2167C19.7976 6.82046 19.2174 6.11822 18.6591 5.72415C18.0196 5.27268 17.2056 5.09021 16.5 5.09021C16.0218 5.09021 15.5317 5.26538 14.9893 5.62604C14.4298 5.99808 13.9364 6.48227 13.4234 6.99526L12 8.41864L10.5766 6.99526ZM22 8.09021C22 12.1883 19.6488 14.2711 15.2216 18.1928C14.3422 18.9718 13.3808 19.8234 12.3397 20.7777C12.1476 20.9539 11.8524 20.9539 11.6603 20.7777C10.6192 19.8234 9.65782 18.9718 8.77838 18.1928C4.35123 14.2711 2 12.1883 2 8.09021C2.5 4.09021 5.5 3.09021 7.5 3.09021C9.47994 3.09021 10.9699 4.56026 11.9698 5.55996C11.9768 5.56701 11.9838 5.57404 11.9908 5.58104L12 5.59021L12.0092 5.58104C12.0162 5.57404 12.0232 5.56701 12.0302 5.55996C13.0301 4.56026 14.5201 3.09021 16.5 3.09021C18.5 3.09021 21.5 4.09021 22 8.09021Z' fill='%232D2D2D'/%3E%3C/svg%3E%0A") no-repeat !important;background-size:24px !important}.job-reaction-save svg path{display:none}.job-reaction-unsave svg{background:url("data:image/svg+xml,%3Csvg width='24' height='24' viewBox='0 0 24 24' fill='none' xmlns='http://www.w3.org/2000/svg'%3E%3Cpath d='M11.6663 20.7871C11.8564 20.9569 12.1437 20.9569 12.3336 20.7868L13.45 19.787C18.6 15.2099 22 12.1884 22 8.48557C22 5.46414 19.575 3.08557 16.5 3.08557C14.7625 3.08557 13.0875 4.397 12 5.657C10.9125 4.397 9.2375 3.08557 7.5 3.08557C4.425 3.08557 2 5.46414 2 8.48557C2 12.1884 5.4 15.2099 10.55 19.7999C10.55 19.791 11.2381 20.4045 11.6663 20.7871Z' fill='%232D2D2D'/%3E%3C/svg%3E%0A") no-repeat !important;background-size:24px !important}.job-reaction-unsave svg path{display:none}.job-reaction-kebab-item.job-reaction-save svg{background:url("data:image/svg+xml,%3Csvg width='24' height='24' viewBox='0 0 24 24' fill='none' xmlns='http://www.w3.org/2 ...
#      </style>
#      <link href="//d3fw5vlhllyvee.cloudfront.net/s/503c00f/jasx.css" rel="stylesheet" type="text/css"/>
#      <link href="//d3fw5vlhllyvee.cloudfront.net/s/b014802/serp.css" rel="stylesheet" type="text/css"/>
#      <link href="//d3fw5vlhllyvee.cloudfront.net/s/e1a8c5c/jasxreplaceautocompletetest.css" rel="stylesheet" type="text/css"/>
#      <link href="//d3fw5vlhllyvee.cloudfront.net/s/b834b98/jasx_noleftrail_tst.css" rel="stylesheet" type="text/css"/>
#      <style>
#       body.janus #resultsCol .row.result .jobtitle{margin-right:2.125rem !important}body.rtl.janus #resultsCol .row.result .jobtitle{margin-left:2.125rem !important;margin-right:0 !important}
#      </style>
#      <style>
#       .seo-breadcrumbs{margin-top:12px;display:flex;justify-content:flex-start;font-size:0.833rem}[dir="ltr"] .seo-breadcrumbs{padding-left:24px}[dir="rtl"] .seo-breadcrumbs{padding-right:24px}.seo-breadcrumbs-centered{margin-top:12px;display:flex;justify-content:flex-start;font-size:0.833rem}body.janus div.seo-breadcrumbs a.seo-breadcrumbLink,body.janus div.seo-breadcrumbs-centered a.seo-breadcrumbLink{color:#000 !important}
#      </style>
#      <style type="text/css">
#       #resultsBody #pageContent #resultsCol .row .location{font-size:1rem;line-height:1.38}.jasxrefreshcombotst #resultsBody #pageContent #resultsCol .row .location{line-height:1.5rem}#resultsBody #pageContent #resultsCol .row .serp-ResponsiveEmployer .serp-ResponsiveEmployer-heading,#resultsBody #pageContent #resultsCol .row .snip .summary,#resultsBody #pageContent #resultsCol .row.unifiedRow .summary{font-size:0.875rem !important;line-height:1.25 !important}#resultsBody #pageContent #resultsCol .row .salarySnippet .salary{font-size:0.875rem;line-height:1.25}.jasxrefreshcombotst #resultsBody #pageContent #resultsCol .row .salarySnippet .salary{line-height:1rem;display:inline-block}#resultsBody #pageContent #resultsCol .row .result-link-bar-container .result-link-bar span,#resultsBody #pageContent #resultsCol .row .result-link-bar-container .result-link-bar a,#resultsBody #pageContent #resultsCol .row .result-link-bar-container .result-link-bar div{font-size:0.75rem !important}#resultsBody #pageContent #resultsCol .row .slNoUnderline{font-size:0.875rem !important;line-height:1 !important}.desktopAurora #resultsBody #pageContent #resultsCol .row .slNoUnderline{font-size:0.75rem !important}#resultsBody #pageContent #resultsCol .row .jobtitle a{font-size:1.125rem !important;line-height:1.5 !important}#resultsBody #pageContent #resultsCol .row .jobtitle .new,#resultsBody #pageContent #resultsCol .row .iaP .iaLabel{font-size:0.875rem !important;line-height:1.25 !important}.jasxrefreshcombotst #resultsBody #pageContent #resultsCol .row .jobtitle .new{font-size:0.75rem !important;line-height:0.75rem !important}#resultsBody #pageContent #resultsCol .row a.jobtitle{font-size:1.125rem !important;line-height:1.5 !important}#resultsBody #pageContent #resultsCol .row span.new,#resultsBody #pageContent #resultsCol .row .iaP .iaLabel{font-size:0.875rem !important;line-height:1.25 !important}.jasxrefreshcombotst #resultsBody #pageContent #resultsCol .row span.new{font-size:0.75rem !important;line-height:0.75rem !important}.ita-inline-job .sponsored{font-size:0.75rem !important}#resultsBody #pageContent #resultsCol .row .sdn{font-size:0.75rem !important}
#      </style>
#      <link href="//d3fw5vlhllyvee.cloudfront.net/s/45bf26e/jobCardDensityTest.css" rel="stylesheet" type="text/css"/>
#      <style type="text/css">
#       .row .snip .salary,.row .sjcl .salarySnippet span,.row.unifiedRow .salarySnippet .salary{color:#000 !important;font-size:0.875rem;font-weight:bold !important;line-height:1.43rem}
#      </style>
#      <link href="https://fonts.googleapis.com/css?family=Noto+Sans" rel="stylesheet"/>
#      <style type="text/css">
#       body.janus.miniRefresh *,[dir=ltr] body.miniRefresh div .gnav .icl-GlobalFooter-link,[dir=rtl] .gnav .icl-GlobalFooter-link{font-family:'Noto Sans','Helvetica Neue',Helvetica,Arial,sans-serif !important}
#      </style>
#      <style type="text/css">
#       .searchCount-a11y-contrast-color,.currentSearchLabel-a11y-contrast-color,.sortByLabel-a11y-contrast-color{color:#6f6f6f !important}.desktopAurora .currentSearchLabel-a11y-contrast-color{color:#767676 !important}.desktopAurora .jobAlertFormLabel-a11y-contrast-color{color:#2d2d2d}.jobAlertFormLabel-a11y-contrast-color{color:#6f6f6f}
#      </style>
#      <style type="text/css">
#       .accessible-contrast-color-location{color:#2d2d2d !important}
#      </style>
#      <link href="//d3fw5vlhllyvee.cloudfront.net/s/7405a19/Callout.css" rel="stylesheet" type="text/css">
#       <link href="//d3fw5vlhllyvee.cloudfront.net/s/3732310/CloseButton.css" rel="stylesheet" type="text/css"/>
#       <link href="//d3fw5vlhllyvee.cloudfront.net/s/731b2e7/jobalertsavedjobs.css" rel="stylesheet" type="text/css"/>
#       <meta content="259 Healthcare jobs available in Sacramento, CA on Indeed.com. Apply to Administrative Assistant, Surgery Scheduler, Receptionist and more!" name="description"/>
#       <meta content="Healthcare Jobs, Employment in Sacramento, CA, Sacramento, CA careers, Sacramento, CA employment, Sacramento, CA job listings, Sacramento, CA job search, Sacramento, CA search engine, work in Sacramento, CA" name="keywords"/>
#       <meta content="origin-when-cross-origin" name="referrer"/>
#       <link href="/q-Entry-Level-Healthcare-l-Sacramento,-CA-jobs.html" rel="canonical"/>
#       <link href="/jobs?q=healthcare&amp;l=Sacramento&amp;radius=15&amp;explvl=entry_level&amp;start=10" rel="next">
#        <script src="https://d3fw5vlhllyvee.cloudfront.net/mosaic-common/dist/2af0f208635b9be67a4c/scripts/shim.js?cacheKey=1" type="text/javascript">
#        </script>
#        <link href="//d3fw5vlhllyvee.cloudfront.net/s/2bbfa01/jobCardHolisticRedesign.css" rel="stylesheet" type="text/css"/>
#        <script type="text/javascript">
#         var dcmPayload = 'jobse0;jobal0;viewj0;savej0;6927552';
# var indeedCsrfToken = 'poCn1mRNhOnhaXrEtvCZMJzPQ13BjxKJ';
# var hashedCsrfToken = '939e0f23b35bcbb86c9faecd0eb5d6c6';
# var sharedCookieDomainForSmartApply = '.indeed.com';
#        </script>
#        <script>
#         initJavascriptGroups({"73c1c24c17a1585cab090f60f8c5fc79c788b32cc9d81dc26199186f634c3923":[-1,null],"d9a67eed22a5cd06f0eb41a45eda84aaae1bbf505d852b8bc3d630e4e6382414":[-1,null],"c999997ba6aa1b6881f335b3479ff7c77095d80af583ea479885b3e47b9cf726":[1,null],"25b54f97c57c2a255b45d04ac4c971c0bf472556fdbe43828ac79e0968631ebb":[1,null],"07b088335a0ae1a029091a2f26548fc48e7cae8eac28ed663f6260b3c1372c7d":[-1,null],"33c702625b69a177bde1650dce2a34feff29f3cfb8e30f8d00ab9526205b0ed4":[-1,null],"b6f0433c248484865fcf38b346f2c5af467936919986b2260ba10e925860158a":[2,null],"90981c400895faedd3e169efce6f570e2bd54b731fe0a8ccd4ea35853c856254":[-1,null],"4dc0081a9fa299429499c75533359d2c1b3359658955a46a632305adbdfcb589":[6,null],"6d23eea71158691303229243140eaac28d46283974abf8ede52556b9431fedf5":[-1,"sponsoredGray"],"5f4715d89442162447ad23a85839631e9e84db91c8ac165fd783105450b1ba26":[1,null],"578033ef854ff6ed4a8c67b1c26d2b56566a03d423cac2e93d0799e733c88421":[1,null],"efa89b73720c215b428e0cf8114a311f703342c7195c46d282c062bcdeab4766":[1,null],"40a9f173a14ebbbdac25c0d95ed4d0f04a98b9aeee1acf5e9d5b1a8060d0398f":[-1,null],"7aa3047cbd2757fcf2a0147286062de8780277da2187cb35692ec8d902e377ee":[-1,0],"a350dab82c5df4e9ed69d047c8f6efcdde0f4a3b0a91cdc78a9b6fa310f9df9a":[1,["jobse0","jobal0","viewj0","savej0","6927552"]],"618eb58e0797fb61e6e2f35cbc17f5b1f830af0f0e07fd9fcdb1d2033968aad7":[1,null],"78b65fcdcde593fe9bc311aa67e58a68dba24f817c1f93576cf4bb0083938dfa":[1,null],"7f10ee5e41f69dcbd4f45fd84211f69e006c6fd60c4e8107e218d33c9f54da1c":[-1,null],"497283cccc19cba4b0a929496834fca9b8774fd0e6ae0f3b97fcde60af98252f":[-1,[]],"e0f2d7d6ba6f1f84512fceea47bbf4471d9ce64b04ecd4a14708599b11502cad":[-1,null]});
#
# function onLoadHandler() {
#
# document.js.reset();
# jobSeenInit('1ev2taqp33kmi002', [{
# 'jobClassName': 'result',
# 'scanIta': true,
# 'containsSponsored': true,
# 'context': ''
# }]);
#
# if ( document.radius_update ) { document.radius_update.reset(); }
#
#
# initJobsearchUnloadBeacon('1ev2taqp33kmi002');
#
#
# initDwellPerformanceLogging('1ev2taqp33kmi002', 'jasx');
# initWindowDwellLogging('jasx', '1ev2taqp33kmi002', 'serp');
#
#
# initSponsoredJobScreenerQuestions();
#
# initIndeedApply('https://www.indeed.com');
#
# }
#
# initLogInitialUserInteraction('1ev2taqp33kmi002', 'serp');
#
# window.onload = onLoadHandler;
#        </script>
#        <link href="android-app://com.indeed.android.jobsearch/https/www.indeed.com/m/jobs?q=healthcare&amp;l=Sacramento&amp;radius=15&amp;explvl=entry_level" rel="alternate"/>
#        <link href="ios-app://https/www.indeed.com/m/jobs?q=healthcare&amp;l=Sacramento&amp;radius=15&amp;explvl=entry_level" rel="alternate"/>
#        <title>
#         Healthcare Jobs, Employment in Sacramento, CA
#        </title>
#        <style type="text/css">
#         #filter-salary-estimate{order:2147483647}#filter-experience-level{order:2147483647}#filter-job-type{order:2147483647}#filter-distance{order:2147483647}#filter-location{order:2147483647}#filter-company{order:2147483647}#filter-remote{order:2147483647}#filter-language{order:2147483647}#rb_Title{order:2147483647}#filter-taxo1{order:2147483647}#filter-taxo2{order:2147483647}#filter-taxo3{order:2147483647}#filter-taxo4{order:2147483647}#rb_MoreOptions{order:2147483647}
#        </style>
#        <style type="text/css">
#         #refineresults{display:flex;flex-direction:column}#refineresultscol .clearRSControl{margin-bottom:0 !important}.rbSection .more_link,.rbSection .rbList{margin-bottom:0 !important}.rbList+.more_link{margin-top:1rem !important}.rbSection .rbList li:last-child{margin-bottom:0 !important}span[role="heading"]+div{margin-bottom:24px !important}#refineresults span[role="heading"]+div .no-wrap{margin-bottom:0 !important}
#        </style>
#        <script type="application/ld+json">
#         {"@context":"https://schema.org","@type":"BreadcrumbList","itemListElement":[{"@type":"ListItem","position":1,"name":"Healthcare Administrative Support","item":"https://www.indeed.com/q-Healthcare-Administrative-Support-l-Sacramento-jobs.html"},{"@type":"ListItem","position":2,"name":"Healthcare","item":"https://www.indeed.com/q-Healthcare-l-Sacramento-jobs.html"}]}
#        </script>
#        <script type="text/javascript">
#         window['mosaicPlatformModel']= {"mosaicReportContentProviderResponse":{"providerId":"mosaic-provider-reportcontent"},"shouldLoadMosaicProviderDockedMessaging":false};
#        </script>
#        <link href="https://d3fw5vlhllyvee.cloudfront.net/mosaic-common/dist/fee07f4157b728f66630/styles/index.css?cacheKey=1" rel="stylesheet">
#         <link href="https://d3fw5vlhllyvee.cloudfront.net/mosaic-provider-reportcontent/dist/a6c4d545791922d93c11/css/ReportContent-client.css" rel="stylesheet">
#          <link href="https://d3fw5vlhllyvee.cloudfront.net/mosaic-provider-jobsearch-feedback/dist/8fd4002436d2e27242e6/css/SerpFeedback-client.css" rel="stylesheet"/>
#          <link href="https://d3fw5vlhllyvee.cloudfront.net/mosaic-provider-jsfe-salary/dist/a1e6e860bfe4ec49aec7/css/Main-client.css" rel="stylesheet"/>
#          <link href="https://d3fw5vlhllyvee.cloudfront.net/mosaic-provider-reportcontent/dist/2c37adf94247d5d4e06b/css/SerpReportJob-client.css" rel="stylesheet"/>
#          <link href="/images/favicon.ico" rel="shortcut icon"/>
#         </link>
#        </link>
#       </link>
#      </link>
#     </link>
#    </link>
#   </link>
#  </head>
#  <body class="ltr jasxcustomfonttst-inactive janus miniRefresh jasxrefreshcombotst" data-tn-application="jasx" data-tn-olth="41be357fa1c7dc26c5ee98836f8950b3" data-tn-originlogid="1ev2taqp33kmi002" data-tn-originlogtype="jobsearch">
#   <div aria-label="skip" id="accessibilityBanner" role="navigation">
#    <span id="accessibilityText">
#     Skip to
#     <!-- This is translated before reaching this state -->
#     <a class="accessibilityMenu" href="#jobPostingsAnchor" id="skipToJobs">
#      Job Postings
#     </a>
#     ,
#     <!-- This is translated before reaching this state -->
#     <a class="accessibilityMenu" href="#what" id="skipToSearch">
#      Search
#     </a>
#    </span>
#    <a id="accessibilityClose">
#     Close
#    </a>
#   </div>
#   <script type="text/javascript">
#    createTabBar('1ev2taqp33kmi002');
#   </script>
#   <script>
#    var bta = true;
# var sendMeaningfullyInteractive = false;
# var a11yTwoPaneEnabled = true;
# var ltr = true;
# var vjsExhibitionModel = new indeed.vjsExhibition('auxCol', a11yTwoPaneEnabled, ltr);
# var vjsStable = true;
# //For SERP jobs, the scope of these job are document
# var showDebug = false;
# var sd = showDebug ? '1' : undefined;
# var viewJobOnSerp = new indeed.vjs('1ev2taqp33kmi002', 'vjs', document, vjsExhibitionModel, sd, true, false, bta, a11yTwoPaneEnabled);
# var vjk = viewJobOnSerp.getVJK();
# var vjFrom = viewJobOnSerp.getFrom();
# var vjTk = viewJobOnSerp.getTk();
# var indconvtk = '';
# var vjUrl = viewJobOnSerp.vjUrl(vjk, vjFrom, vjTk, indconvtk);
# var showVjOnSerp = vjsStable;
# var zrp = false;
# var viewportTooSmall = true ? window.innerWidth < 960 : window.innerWidth < 1200;
# if ((zrp || !showVjOnSerp || viewportTooSmall) && vjUrl) {
# window.location.replace(vjUrl);
# } else if (showVjOnSerp) {
# initializeTwoPane();
# }
# function initializeTwoPane() {
# var jobKeysWithInfo = {};
#
# jobKeysWithInfo['1dce212f5dedc777'] = true;
#
# jobKeysWithInfo['2f6841a3fe6a17d1'] = true;
#
# jobKeysWithInfo['ae90e7dd204352e6'] = true;
#
# jobKeysWithInfo['17512b0101b46db7'] = true;
#
# jobKeysWithInfo['aefa0c0a16fb2b64'] = true;
#
# jobKeysWithInfo['4cea01ffb5c3d9b5'] = true;
#
# jobKeysWithInfo['3bb5d4f7e51c7521'] = true;
#
# jobKeysWithInfo['29901fa2cc8a3992'] = true;
#
# jobKeysWithInfo['f799eb6fe7af087b'] = true;
#
# jobKeysWithInfo['31b62381b5555688'] = true;
#
# jobKeysWithInfo['f39fa1f5658f8317'] = true;
#
# jobKeysWithInfo['47e7d6161d66881f'] = true;
#
# jobKeysWithInfo['48922017a74dc125'] = true;
#
# jobKeysWithInfo['e0a9a74b20710443'] = true;
#
# jobKeysWithInfo['bb389293e577a75c'] = true;
#
# if (vjk && !jobKeysWithInfo.hasOwnProperty(vjk)) {
# jobKeysWithInfo[vjk] = true;
# }
# if (false) {
# viewJobOnSerp.preloadDescs(jobKeysWithInfo);
# }
# viewJobOnSerp.browserNavigationHandler();
# window.bindAndRender = function () {
# if (showVjOnSerp) {
# window['2paneEnabled'] = true;
# viewJobOnSerp.bindJobKeys(jobKeysWithInfo, sendMeaningfullyInteractive);
# if (vjUrl) {
# viewJobOnSerp.renderOnJobKey(vjk, 'vjs', '1ev2taqp33kmi002', '', undefined, undefined, function () {
# window.location.replace(vjUrl);
# }, function() {
#
# restore('savedjobs');
#
# });
# }
# }
# };
# }
#   </script>
#   <script id="_indeed_gnav_config" type="application/json">
#    {"isEmployer":false,"primaryURL":"https://www.indeed.com/","requestURL":"http://www.indeed.com/jobs?q=healthcare\u0026l=Sacramento\u0026radius=15\u0026explvl=entry_level","from":"gnav-menu-jobsearch--jasx","headerVariant":"DESKTOP_JOBSEEKER","isShowSmallHeader":true,"desktopPageLinks":[{"text":"Find jobs","href":"https://www.indeed.com/","dataHref":"https://www.indeed.com/?from=gnav-jobsearch--jasx","isHighlighted":true,"dataGnavElementName":"FindJobs"},{"text":"Company reviews","href":"https://www.indeed.com/companies","dataHref":"https://www.indeed.com/companies?from=gnav-jobsearch--jasx","isHighlighted":false,"dataGnavElementName":"CompanyReviews"},{"text":"Find salaries","href":"https://www.indeed.com/salaries","dataHref":"https://www.indeed.com/salaries?from=gnav-jobsearch--jasx","isHighlighted":false,"dataGnavElementName":"FindSalaries"}],"resumeLink":{"text":"Upload your resume","href":"https://www.indeed.com/promo/resume","dataHref":"https://www.indeed.com/promo/resume?from=gnav-jobsearch--jasx","isHighlighted":false,"dataGnavElementName":"UploadYourResume"},"skipNavLinkModel":{"href":"#gnav-header-end","text":"Skip to main content","dataGnavElementName":"SkipNav"},"variantToggleLink":{"text":"Employers / Post Job","href":"https://www.indeed.com/hire?co=US\u0026hl=en","dataHref":"https://www.indeed.com/hire?co=US\u0026hl=en\u0026from=gnav-menu-jobsearch--jasx\u0026ikw=gnav-header-hire\u0026isid=employerlink-US","clickTrackingKey":"EmployersPostJob","dataGnavElementName":"EmployersPostJob"},"country":"US","logoHref":"/?from=gnav-jobsearch--jasx","logoName":"aurora","appName":"jobsearch--jasx","inboxApiHref":"https://messages.indeed.com/messaging/jobseekers/v2/summary?from=gnav-util-jobsearch--jasx\u0026gnavTK=1ev2taqpbt5i4800\u0026tk=\u0026co=US\u0026hl=en\u0026clientApp=GNAV","inboxHref":"https://messages.indeed.com?from=gnav-util-jobsearch--jasx\u0026gnavTK=1ev2taqpbt5i4800\u0026tk=\u0026co=US\u0026hl=en","logRoute":"https://t.indeed.com/gnav/log?from=jobsearch--jasx-serp\u0026parentLogId=1ev2taqpbt5i4800\u0026hostAppTk=","inboxLogTuple":"gnavInbox:12140b7982d032f1660f59e3e976c72d","isInboxTestActive":false,"isShowInboxIcon":false,"inboxTestBucket":-1,"selectedIcon":"","shouldLowerNavIconMinWidth":true,"inboxLogType":"gnavInbox","inboxLth":"12140b7982d032f1660f59e3e976c72d","notificationApiHref":"https://www.indeed.com/notifications/api/1/getNotificationsCount?client=gnav\u0026from=gnav-util-jobsearch--jasx\u0026gnavTK=1ev2taqpbt5i4800\u0026tk=\u0026co=US","notificationHref":"https://www.indeed.com/notifications?from=gnav-util-jobsearch--jasx\u0026gnavTK=1ev2taqpbt5i4800\u0026tk=\u0026co=US\u0026hl=en","isNotificationTestActive":false,"isShowNotificationIcon":false,"notificationTestBucket":-1,"notificationLogType":"gnavNotification","notificationLth":"6d669dfa33371660f3e683b38b9f3ddc","isOnlineStatusActive":false,"onlineStatusApiHref":"https://employers.indeed.com/api/v2/messaging/onlinestatus/jobseeker?indeedcsrftoken=\u0026indeedClientApplication=gnav\u0026isClosed=false","serviceRequestLogUID":"1ev2taqpbt5i4800","hostAppTk":"","canonicalPageId":"","jsErrorLogType":"gnavJSError","jsErrorLth":"6411ec182c6acd8714dc2d03716eed1d","jsEnabledLogType":"gnavJSEnabled","jsEnabledLth":"5e9311c1001227ca5c6c32db123fb854","interactionLogType":"gnavInteraction","interactionLth":"87caa20c31fa9e447264b1615339f1ce","clickLogType":"gnavClick","clickLth":"fa8b0aff9499e52dd7e9215032d9ad9f","pageSpeedLogType":"gnavPageSpeed","pageSpeedLth":"12783140239867f5afc3bd80a743e013","dwellTimeLogType":"gnavDwellTime","dwellTimeLth":"e415e44ee819f056fc4675c1b0373740","isPageSpeedLoggingEnabled":true,"passportAccountText":"Sign in","passportAccountURL":"https://secure.indeed.com/account/login?hl=en_US\u0026co=US\u0026continue=https%3A%2F%2Fwww.indeed.com%2Fjobs%3Fq%3Dhealthcare%26l%3DSacramento%26radius%3D15%26explvl%3Dentry_level\u0026tmpl=desktop\u0026service=my\u0026from=gnav-util-jobsearch--jasx","showSecondaryStyleSignInButton":true,"passp ...
#   </script>
#   <link href="https://d3fw5vlhllyvee.cloudfront.net/dist/b2d42fa5a1c5232768a3/styles/desktop_jobseeker_header_external.css" rel="stylesheet" type="text/css"/>
#   <nav aria-label="Primary" class="gnav" id="gnav-main-container">
#    <div class="main" data-gnav-region="Main" data-reactroot="">
#     <div class="gnav-DesktopHeaderContainer">
#      <div class="gnav-DesktopHeader is-small-header with-skip-nav">
#       <button class="icl-Button icl-Button--primary icl-Button--lg gnav-SkipNavLink" data-gnav-element-name="SkipNav" type="button">
#        <span class="gnav-SkipNavLink-text">
#         Skip to main content
#        </span>
#       </button>
#       <div class="gnav-DesktopHeader-logo">
#        <a class="gnav-Logo" data-gnav-element-name="Logo" href="/?from=gnav-jobsearch--jasx" title="">
#         <span class="gnav-sr-only">
# ...
# /*# sourceMappingURL=Button.css.map*/
#           </style>
#           <div id="resumeCtaFooter" style="height:64px;">
#            <div style="position:absolute;width:100%;">
#             <style type="text/css">
#              .footerCta {
#                         text-align:center;
#                         margin:0;
#                         font-size:0.9375rem;
#                         width:100%;
#                         background-color:#ebebeb;
#                         color:#000000;
#                     }
#
#                     div.content >table {
#                         margin-bottom: 4em;
#                     }
#             </style>
#             <script type="text/javascript">
#              if(null !== call_when_jsall_loaded) {call_when_jsall_loaded(function() {if(!!window.logPromoImpression) {window.logPromoImpression('trk.origin=jobsearch&trk.variant=FooterGrayBelow&trk.pos=below&trk.tk=1ev2taqp33kmi002', 'resume');}})}
#             </script>
#             <div class="footerCta greyBar">
#              Let Employers Find You
#              <style type="text/css">
#               .cta_button {
#             text-decoration:none !important;
#             margin: 12px !important;
#         }
#
#         .cta_button.blue  {
#             color: #f8f8f9 !important;
#         }
#
#         .cta_button.grey {
#             color: #000000 !important;
#         }
#
#         .cta_button.uploaded {
#             border-radius: 100px !important;
#             font-size: 0.75rem;
#             line-height: 1rem;
#             text-align: center;
#             padding: 8px;
#         }
#
#         .cta_button.continue {
#             color: #085ff7 !important;
#             background-color: #ffffff !important;
#             border: 2px solid #195ff7 !important;
#             width: 163px;
#         }
#
#         .cta_button.accept {
#             color: #ffffff !important;
#             background-color: #085ff7 !important;
#             border: 2px solid #085ff7 !important;
#             width: 106px;
#             display: inline-block;
#         }
#
#         .cta_button.back {
#             color: #085ff7 !important;
#             background-color: #ffffff !important;
#             border: 2px solid #cccccc !important;
#             width: 106px;
#             margin-left: -4px !important;
#         }
#              </style>
#              <span dir="ltr">
#               <a class="icl-Button icl-Button--primary icl-Button--sm cta_button blue" href="/promo/resume?from=bottomResumeCTAjobsearch&amp;trk.origin=jobsearch" onclick="if(!!window.logPromoClick) {window.logPromoClick('trk.origin=jobsearch&amp;trk.variant=FooterGrayBelow&amp;trk.pos=below&amp;trk.tk=1ev2taqp33kmi002', 'resume','/promo/resume?from=bottomResumeCTAjobsearch&amp;trk.origin=jobsearch');}">
#                Upload Your Resume
#               </a>
#              </span>
#             </div>
#            </div>
#           </div>
#          </div>
#         </link>
#        </link>
#       </link>
#      </td>
#     </tr>
#    </tbody>
#   </table>
#   <script type="text/javascript">
#    logJSVPing('jsv', '1ev2taqp33kmi002');
# function jsall_loaded() {
#
# initProcessLeftoverDwellEntries();
#
# detectBrowserState('jobsearch', '1ev2taqp33kmi002');
#
# initLogTiming('jobsearch', '1ev2taqp33kmi002', 'SB/9+iW9K31gv1P+NvWHPGvBuR3cPi2aWBMBI/hSKmk=');
# attachSjBlock('');
# attachJaBlock('');
# }
# if (window['closureReady'] === true) {
# jsall_loaded();
# }
#   </script>
#   <script type="text/javascript">
#    PENDING_ANALYTICS_VARS = window.PENDING_ANALYTICS_VARS || [];
# PENDING_ANALYTICS_VARS[PENDING_ANALYTICS_VARS.length] = ['_setCustomVar', 5, 'loggedIn', 'false', 3];
#   </script>
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=DC-6927552">
#   </script>
#   <script>
#    window.dataLayer = window.dataLayer || [];
# function gtag(){dataLayer.push(arguments);}
# gtag('js', new Date());
# gtag('config', 'DC-6927552');
#   </script>
#   <script type="text/javascript">
#    var ga_domains = [];
# ga_domains.push('indeed.co.in');ga_domains.push('indeed.lu');ga_domains.push('indeed.fr');ga_domains.push('indeed.de');ga_domains.push('indeed.com.br');ga_domains.push('indeed.co.uk');ga_domains.push('indeed.hk');ga_domains.push('indeed.fi');ga_domains.push('indeed.pt');ga_domains.push('indeed.jp');ga_domains.push('indeed.com');ga_domains.push('indeed.com.sg');ga_domains.push('indeed.nl');ga_domains.push('indeed.com.pk');ga_domains.push('indeed.cl');ga_domains.push('indeed.es');ga_domains.push('indeed.co.ve');ga_domains.push('indeed.ae');ga_domains.push('indeed.com.mx');ga_domains.push('indeed.com.my');ga_domains.push('indeed.ch');ga_domains.push('indeed.com.co');ga_domains.push('indeed.com.ph');ga_domains.push('indeed.co.za');ga_domains.push('indeed.ie');ga_domains.push('indeed.com.au');ga_domains.push('indeed.ca');ga_domains.push('indeed.com.pe');
#
# (function (i, s, o, g, r, a, m) {
# i['GoogleAnalyticsObject'] = r;
# i[r] = i[r] || function () {
# (i[r].q = i[r].q || []).push(arguments)
# }, i[r].l = 1 * new Date();
# a = s.createElement(o),
# m = s.getElementsByTagName(o)[0];
# a.async = 1;
# a.src = g;
# m.parentNode.insertBefore(a, m)
# })(window, document, 'script', '//www.google-analytics.com/analytics.js', 'ga');
#
# var ga = ga || [];
# ga('create', 'UA-90780-1', 'auto', {
# 'allowLinker': true
# });
# ga('require', 'linkid');
# ga('require', 'linker');
# ga('linker:autoLink', ga_domains, false, true);
# ga('require', 'displayfeatures');
# ga('send', 'pageview');
#
# (function () {
# if (window.PENDING_ANALYTICS_VARS && window.PENDING_ANALYTICS_VARS.length > 0) {
# for (var i in PENDING_ANALYTICS_VARS) {
# ga('set', PENDING_ANALYTICS_VARS[i][2], PENDING_ANALYTICS_VARS[i][3]);
# }
# }
# })();
#   </script>
#   <script>
#    window._comscore = window._comscore || [];
# window._comscore.push({ c1: "2", c2: "6486505", c4:"www.indeed.com/jobs", c15:"1ev2taqog3kmi000"});
# (function() { var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true; s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js"; el.parentNode.insertBefore(s, el); })();
#   </script>
#   <noscript>
#    <img alt="" height="0" src="https://sb.scorecardresearch.com/p?c1=2&amp;c2=6486505&amp;c4=www.indeed.com%2Fjobs&amp;c15=1ev2taqog3kmi000&amp;cv=2.0&amp;cj=1" style="display:none" width="0"/>
#   </noscript>
#   <img alt="" aria-hidden="true" height="0" referrerpolicy="no-referrer" src="https://match.prod.bidr.io/cookie-sync/indeed?buyer_user_id=1ev2taqog3kmi000" style="display:none" width="0"/>
#   <script id="mosaic-init-data" type="text/javascript">
#    window.mosaic= window.mosaic || {};
#     window.mosaic.providers={"mosaic-provider-reportcontent":"https://d3fw5vlhllyvee.cloudfront.net/mosaic-provider-reportcontent/dist/a6674633b46a2be78341/js/ReportContent-client.js","mosaic-provider-jobsearch-feedback":"https://d3fw5vlhllyvee.cloudfront.net/mosaic-provider-jobsearch-feedback/dist/8cd3c1ac52b1b967bc2a/js/SerpFeedback-client.js","platformJs":"https://d3fw5vlhllyvee.cloudfront.net/mosaic-common/dist/2cc3c50f40ced320689e/scripts/index.js?cacheKey\u003d1","mosaic-provider-jsfe-salary":"https://d3fw5vlhllyvee.cloudfront.net/mosaic-provider-jsfe-salary/dist/94f2229b1ab9f5c3f678/js/Main-client.js","mosaic-provider-serpreportjob":"https://d3fw5vlhllyvee.cloudfront.net/mosaic-provider-reportcontent/dist/37fa360cd2f00a61e032/js/SerpReportJob-client.js"};
#     window.mosaic.providerErrors={};
#     window.mosaic.provideri18N={"mosaic-provider-reportcontent":"https://d3fw5vlhllyvee.cloudfront.net/mosaic-provider-reportcontent/dist/i18n/37ed84761bddac391a2d/en_US.js","mosaic-provider-jobsearch-feedback":"https://d3fw5vlhllyvee.cloudfront.net/mosaic-provider-jobsearch-feedback/dist/i18n/826255d9f7a50859c2cb/en_US.js","mosaic-provider-jsfe-salary":"https://d3fw5vlhllyvee.cloudfront.net/mosaic-provider-jsfe-salary/dist/i18n/ef3fdd6707f0b639237f/en_US.js","mosaic-provider-serpreportjob":"https://d3fw5vlhllyvee.cloudfront.net/mosaic-provider-reportcontent/dist/i18n/37ed84761bddac391a2d/en_US.js"};
#     window.mosaic.lazyProviders={"mosaic-provider-reportcontent":"\u003cdiv class\u003d\"reportcontent-injection-wrapper\"\u003e\u003c/div\u003e"};
#     window.mosaic.cssResetProviders={"mosaic-provider-reportcontent":false,"mosaic-provider-jobsearch-feedback":false,"mosaic-provider-jsfe-salary":false,"mosaic-provider-serpreportjob":false};
#     window.mosaic.canaryProviders={"mosaic-provider-reportcontent":false,"mosaic-provider-jobsearch-feedback":true,"mosaic-provider-jsfe-salary":false,"mosaic-provider-serpreportjob":false};
#     window.mosaic.zonedProviders={"afterFifthJobResult":[],"salaryFilter":["mosaic-provider-jsfe-salary"],"afterTenthJobResult":[],"jobcards":[],"belowJobResultsPagination":[],"serpModals":[],"belowPageContent":[],"aboveJobCards":["mosaic-provider-serpreportjob"]};
#     window.mosaic.serviceIdLookup={"mosaic-provider-reportcontent":"mosaic-provider-reportcontent","mosaic-provider-jobsearch-feedback":"mosaic-provider-jobsearch-feedback","mosaic-provider-jsfe-salary":"mosaic-provider-jsfe-salary","mosaic-provider-serpreportjob":"mosaic-provider-reportcontent"};
#     window.mosaic.shouldLogProviderContainerClicks={"mosaic-provider-reportcontent":false,"mosaic-provider-jsfe-career-questions":true,"mosaic-provider-jobsearch-feedback":true,"mosaic-provider-jsfe-salary":true,"mosaic-provider-serpreportjob":true};
#     window.mosaic.webpackPublicPath="https://d3fw5vlhllyvee.cloudfront.net/mosaic-common/dist";
#     window.mosaic.config = {
#         proctor: {"mosaic_platform_phasedinit_tog":{"name":"active","value":1},"mosaic_platform_json_as_string_tst":{"name":"inactive","value":-1},"mosaic_platform_load_defer":{"name":"inactive","value":-1}}
#     };
#   </script>
#   <script id="mosaic-data" type="text/javascript">
#    window.mosaic.providerData={};
#     window.mosaic.initialData = {"logTypes":{"jsuipPlatformInitError":"4327faee2bbb67f4e7f2185701a52e54","mosaicPlatformLoadRecovery":"cee115a2f7013215fe1cde93caa21161","mosaicUserInteraction":"3d8d54584153dd9f2adb9523b9d6135e","mosaicProviderSeen":"e3926cc0a343f384f2e5e6dfc540016a","jsuipProviderLoadTimings":"fb7274d51fc7a04d450086c83a40cc6a","jsuipProviderExecutionError":"211e778edbde5e164fd5f14dd23e6115","jsuipAction":"d5973eb3ad332b3608839e9bbed7d867","jsuipPlatformLoadError":"c74c8d65f1d6f620ddce517edd3faa40","jsuipProviderLoadError":"61c37c1721757c82be5e97b1fff8d1c2"},"platformLogTk":"1ev2taqt43kmi000","logTk":"1ev2taqp33kmi002","hostId":"jasx","platformId":"jasx","env":"PRODUCTION","pageId":"serp"};
#
#     window.mosaic.providerData["mosaic-provider-reportcontent"]={"hostId":"jasx","pageId":"serp","ctk":"1ev2taqog3kmi000","country":"US","language":"en","userAgent":"python-requests/2.25.1","mobvjtk":"1ev2taqp33kmi002","isMobile":false,"indeedcsrftoken":"","isLoggedIn":false,"isConfirmed":true,"reportContentApiUrl":"https://reportcontent.indeed.com/api/v1/report/content","showAsButton":true};
#     window.mosaic.providerData["mosaic-provider-jobsearch-feedback"]={"name":"Feedback","pageId":"serp","country":"US","language":"en","ctk":"1ev2taqog3kmi000","userAgent":"python-requests/2.25.1","metaData":{"feedbackId":"serp-relevance"},"mobile":false,"userId":0,"skipCategories":false,"seenData":{"feedbackId":"serp-relevance"},"eventData":{"feedbackId":"serp-relevance"},"proctorGroups":{"mobvjreportbuttontst":{"group":"inactive","value":-1,"allocationId":""},"mobserppostdisliketst":{"group":"inactive","value":-1,"allocationId":"#A2"},"serprelratingverbatimtst":{"group":"inactive","value":-1,"allocationId":""}}};
#     window.mosaic.providerData["mosaic-provider-jsfe-salary"]={"mobile":false,"currency":"USD","currencySymbol":"$","salaryType":"HOURLY","salaryFilterLowerBound":0,"salaryFilterUpperBound":50,"ctk":"1ev2taqog3kmi000","country":"US","language":"en","loggedIn":false,"userId":0,"logEntryTK":"1ev2taqp33kmi002","privileged":false,"platform":"","url":"https://www.indeed.com/jobs?q=healthcare&l=Sacramento&radius=15&explvl=entry_level","cookie":{"SHOE":"","SOCK":""},"pg":{"mosaic_serp_salary_v11_slider_tst":{"group":"inactive","value":-1,"allocationId":""},"mosaic_serp_salary_v11_minslider_tst":{"group":"active","value":1,"allocationId":"#B8"},"mosaic_salary_filter_intl_format_tog":{"group":"active","value":1,"allocationId":"#F2"},"mosaic_mobserp_salary_tog":{"group":"inactive","value":-1,"allocationId":""},"mosaic_dserp_salary_tog":{"group":"pill","value":2,"allocationId":"#A14"}},"pgString":"#B8:mosaic_serp_salary_v11_minslider_tst1,#F2:mosaic_salary_filter_intl_format_tog1,#A14:mosaic_dserp_salary_tog2,mosaic_serp_salary_v11_minslider_tst1,mosaic_salary_filter_intl_format_tog1,mosaic_dserp_salary_tog2","profileAPIPath":"https://profile-api.indeed.com/api","profileAPITimeout":300,"gt":{"split":{}},"locale":"en-US"};
#     window.mosaic.providerData["mosaic-provider-serpreportjob"]={"hostId":"jasx","pageId":"serp","country":"US","language":"en","ctk":"1ev2taqog3kmi000","userAgent":"python-requests/2.25.1","mobvjtk":"1ev2taqp33kmi002","isMobile":false,"isLoggedIn":false,"isConfirmed":true,"reportContentApiUrl":"https://reportcontent.indeed.com/api/v1/report/content"};
#   </script>
#   <script async="" crossorigin="anonymous" src="https://d3fw5vlhllyvee.cloudfront.net/mosaic-common/dist/9b176c92f7b592bd89b4/scripts/loadProviders.js?cacheKey=1">
#   </script>
#   <script id="mosaic-translation-overrides">
#    this.mosaic = this.mosaic || {}; this.mosaic.i18nOverrides = this.mosaic.i18nOverrides || {};
#   </script>
#   <script>
#    window['sendPageLoadEndPing'] = function(pageId, tk, st) {var validPageIds = ['viewjob', 'serp']; if (!!Image && validPageIds.indexOf(pageId) > -1 && !!tk && !!st) {var href = '/rpc/pageLoadEnd?pageId=' + pageId + '&tk=' + tk + '&st=' + st + '&__=' + Math.random(); var img = new Image(); img.src = href;}}; window['sendPageLoadEndPing']("serp", "1ev2taqp33kmi002", "1613931834147");
#   </script>
#   <script type="text/javascript">
#    document.cookie = "jaSerpCount="+ 1 + "; Path=/";
#   </script>
#   <div id="thirdPartyApplyCreateAccountModal">
#   </div>
#   <div id="successfullySignedInModal">
#   </div>
#  </body>
# </html>

# %%
def extract_job_title_from_result(soup): 
    jobs = []
    for div in soup.find_all(name='div', attrs={'class':'row'}):
        for a in div.find_all(name='a', attrs={'data-tn-element':'jobTitle'}):
            jobs.append(a['title'])
    return(jobs)
extract_job_title_from_result(soup)
# Out:
# ['Administrative Assistant for Medical Front Office',
#  'Director of Medical Records',
#  'Medical Scheduler',
#  'Administrative Assistant II',
#  'Unit Secretary - NICU',
#  '(Healthcare) Contracts Administrator 3',
#  'Administrative Assistant II-Purchasing',
#  'Customer Service Representative I',
#  'Certified Medical Assistants needed ASAP!',
#  'Patient Services Representative',
#  'Chiropractic Assistant',
#  'Receptionist',
#  'Surgery Scheduling Clerk-R',
#  'Ambulatory Surgery Center Administrator',
#  'Medical Scribe']

# %%
def extract_company_from_result(soup): 
    companies = []
    for div in soup.find_all(name='div', attrs={'class':'row'}):
        company = div.find_all(name='span', attrs={'class':'company'})
        if len(company) > 0:
            for b in company:
                companies.append(b.text.strip())
        else:
            sec_try = div.find_all(name='span', attrs={'class':'result-link-source'})
            for span in sec_try:
                companies.append(span.text.strip())
    return(companies)
extract_company_from_result(soup)
# Out:
# ['California IVF Fertility Center',
#  'Fairmont Rehabilitation Hospital',
#  'Sacramento Ear, Nose and Throat',
#  'UC Davis Health',
#  'Sutter Health',
#  'UC Davis Health',
#  'UC Davis Health',
#  'Delta Dental',
#  'visit-healthcare',
#  'Sutter Health',
#  'Baratta Holistic Center',
#  'Western Dental & Orthodontics',
#  'Methodist Hospital Sacramento',
#  'Clinical Management Consultants',
#  'Capital OB/GYN, Inc.']

# %%
def extract_location_from_result(soup): 
    locations = []
    spans = soup.findAll('span', attrs={'class': 'location'})
    for span in spans:
        locations.append(span.text)
    return(locations)
extract_location_from_result(soup)
# Out:
# ['Sacramento, CA',
#  'Sacramento, CA',
#  'Sacramento, CA',
#  'Sacramento, CA',
#  'Rancho Cordova, CA 95670 (Prospect Park area)',
#  'Sacramento, CA',
#  'Sacramento, CA',
#  'Carmichael, CA 95608',
#  'Sacramento, CA 95829',
#  'Sacramento, CA 95823 (Valley High-North Laguna area)']

# %%
def extract_summary_from_result(soup): 
    summaries = []
    divs = soup.findAll('div', attrs={'class': 'summary'})
    for div in divs:
        summaries.append(div.text.strip())
    return(summaries)
extract_summary_from_result(soup)
# Out:
# ['Position includes reception, registration, telephones, medical records, and patient scheduling.\nExperience preferred in medical front office.',
#  'High school or equivalent (Preferred).\nIt is essential that candidates have medical record experience in a skilled nursing setting or demonstrate excellent…',
#  'Open to applicants who do not have a high school diploma/GED.\nOpen to applicants who do not have a college diploma.\nRelays necessary messages to staff.',
#  'Responsible for editing/correcting previously signed out cases (Amendments), creating and formatting addendums for signed out cases, and preparing cases for…',
#  'High School Graduate, GED or an equivalent combination of education and experience, plus successful completion of medical terminology course is required.',
#  'As changes in federal law, state law and University policy occur from time to time, The Administrator monitors contracts to ensure continued compliance.',
#  '2 years’ recent experience providing customer service in an administrative capacity- multiline phone, vendor communication, ordering office supplies, filing and…',
#  'High school graduate with diploma or equivalent.\nOne year customer service experience within a call center or with related heavy customer contact experience (i…',
#  'Must be able to give injections.\nTraining will be done in person and via Zoom and Video Modules.\nYou will be working in the field 40-50-hour work weeks.',
#  'Requires knowledge of medical and billing terminology.\nHigh school graduate or equivalent required.\nThe Patient Services Representative accepts patient…',
#  'Answer phones, scheduling appointments, billing, basic computer work.\nWe are utilizing all safety measures including a plastic protector at the front desk;…',
#  'Respond to patient questions and or concerns according to company Policies.\nSome training or experience in using multi-line phones and computers.',
#  'The incumbent provides the hospital with a means of scheduling healthcare services for the community and in a manner, which will best serve the patient and…',
#  'Competency in HR Policies including knowledge with CMS, DHS, and OSHA surveys is a huge plus and previous experience working at an administrative or supervisory…',
#  'Medical Scribe needed for a busy OB/GYN office to work closely with physician , will be responsible for but not limited to, real time charting, retrieving…']

# %%
def extract_date_posted_from_result(soup): 
    dates = []
    spans = soup.findAll('span', attrs={'class': 'date'})
    for span in spans:
        dates.append(span.text)
    return(dates)
extract_date_posted_from_result(soup)
# Out:
# ['30+ days ago',
#  '10 days ago',
#  '22 days ago',
#  '1 day ago',
#  '1 day ago',
#  '2 days ago',
#  '5 days ago',
#  '3 days ago',
#  '23 days ago',
#  '1 day ago',
#  '6 days ago',
#  '8 days ago',
#  '2 days ago',
#  '26 days ago',
#  '19 days ago']

# %%
def extract_summary_from_result_new(soup, current_url=URL): 
    jobs = []
    for div in soup.find_all(name='div', attrs={'class':'row'}):
        for a in div.find_all(name='a', attrs={'data-tn-element':'jobTitle'}):
            print(a)
            print(a['title'])
            print(current_url+a['href'])
            page = requests.get(current_url+a['href'])
            summary_soup = BeautifulSoup(page.text, 'html.parser')
            print(extract_summary_from_result(summary_soup))
            break
    return(jobs)
extract_summary_from_result_new(soup)
# Out:
# <a class="jobtitle turnstileLink" data-tn-element="jobTitle" href="/pagead/clk?mo=r&amp;ad=-6NYlbfkN0C57XTUXzEslpkRU6GhCwIDvJsbjChpRBStfzYmWK420WzX5BopbTU5JdhHvzPoUOpXfPhCp7ProypCwj1V77PpR3behjALz-XoNZwebZA92tYVfHmjMVQ_YRpQSCea4FF7YaPezSZOpBSmFm82iexWxniLSsz4veGz6SXoBBmIrFinqdpawVGUUGH6bkCqvyjvFonuxuOvQZSSZXj7R81hqSt8rqLbUXzBqF2ENepROBBcmTmI6DiD2z_Ac669jtuw8EUwtUA149KJ6sHMj6LOGH-_JdslI8nTX2BcdT3A9Wy-V5QFzQ-30WZhUAuUqEMbG3jpgSjyVHchd3oW7PJ5h9_-7tIZRtHxwhwzxBu3s5iAFAbjgjQcFD5LG7MUeP499o7Y_m09Nld0KPwwtp1znlhu1TYXcZqVtDDJsJ8DQZ80ivq2owzS1LsmfFeHXvy2haEsiJ5LVVeiLVTDMunMj4pE6UIxqYUqyWeEU-DF7Q==&amp;p=0&amp;fvj=1&amp;vjs=3" id="sja0" onclick="setRefineByCookie(['radius', 'explvl']); sjoc('sja0', 0); convCtr('SJ'); rclk(this,jobmap[0],true,0);" onmousedown="sjomd('sja0'); clk('sja0'); rclk(this,jobmap[0],0);" rel="noopener nofollow" target="_blank" title="Administrative Assistant for Medical Front Office">
# Administrative Assistant for Medical Front Office</a>
# Administrative Assistant for Medical Front Office
# https://www.indeed.com/jobs?q=healthcare&l=Sacramento&radius=15&explvl=entry_level/pagead/clk?mo=r&ad=-6NYlbfkN0C57XTUXzEslpkRU6GhCwIDvJsbjChpRBStfzYmWK420WzX5BopbTU5JdhHvzPoUOpXfPhCp7ProypCwj1V77PpR3behjALz-XoNZwebZA92tYVfHmjMVQ_YRpQSCea4FF7YaPezSZOpBSmFm82iexWxniLSsz4veGz6SXoBBmIrFinqdpawVGUUGH6bkCqvyjvFonuxuOvQZSSZXj7R81hqSt8rqLbUXzBqF2ENepROBBcmTmI6DiD2z_Ac669jtuw8EUwtUA149KJ6sHMj6LOGH-_JdslI8nTX2BcdT3A9Wy-V5QFzQ-30WZhUAuUqEMbG3jpgSjyVHchd3oW7PJ5h9_-7tIZRtHxwhwzxBu3s5iAFAbjgjQcFD5LG7MUeP499o7Y_m09Nld0KPwwtp1znlhu1TYXcZqVtDDJsJ8DQZ80ivq2owzS1LsmfFeHXvy2haEsiJ5LVVeiLVTDMunMj4pE6UIxqYUqyWeEU-DF7Q==&p=0&fvj=1&vjs=3
# ['We offer full-time positions and benefits such as: medical, dental, vision, life insurance, supplemental and 401(k) with a company match.', 'Coordinate with IT managers, technicians, developers and other contractors to guide the delivery of new systems.\nKnowledge of project management principles.', 'Open to applicants who do not have a high school diploma/GED.\nOpen to applicants who do not have a college diploma.\nRelays necessary messages to staff.', 'Answer phones, scheduling appointments, billing, basic computer work.\nWe are utilizing all safety measures including a plastic protector at the front desk;…', 'Position includes reception, registration, telephones, medical records, and patient scheduling.\nExperience preferred in medical front office.', 'Medical Scribe needed for a busy OB/GYN office to work closely with physician , will be responsible for but not limited to, real time charting, retrieving…', 'Competency in HR Policies including knowledge with CMS, DHS, and OSHA surveys is a huge plus and previous experience working at an administrative or supervisory…', 'High school diploma or GED.\nThe Admissions Coordinator will treat each resident fairly, kindly, and show them dignity and respect.', 'Respond to high volume inbound calls while compassionately handling questions/concerns.\nHigh school or equivalent (Preferred).', 'Responsible for editing/correcting previously signed out cases (Amendments), creating and formatting addendums for signed out cases, and preparing cases for…', 'High School Graduate, GED or an equivalent combination of education and experience, plus successful completion of medical terminology course is required.', 'As changes in federal law, state law and University policy occur from time to time, The Administrator monitors contracts to ensure continued compliance.', '2 years’ recent experience providing customer service in an administrative capacity- multiline phone, vendor communication, ordering office supplies, filing and…', 'Hours will be approximately 20-30 hours a week, but could increase.\nDuties would include anything from cleaning, assisting with elderly grandfather, casting…', 'High school graduate with diploma or equivalent.\nOne year customer service experience within a call center or with related heavy customer contact experience (i…']
# <a class="jobtitle turnstileLink" data-tn-element="jobTitle" href="/pagead/clk?mo=r&amp;ad=-6NYlbfkN0B8NV38KXLisi_yba08IRslyje1q7o304qlbxR_KnihTVM3FzL_q2U8AxJnHI-_Zx3ffuTXWJ4Ht2__yh7O-lK7qtY--p7xioClx6MtJZSVcU-fXvM9fZpnhFFJX-VjiEVvx37ZKhBjJtHZhHAMQxGzh8tbH9jYY-Ocuu7_pkl6xd1GYKmjZ8MZFDwACPsB4rRQTr-nWmhkSvvmct9HIg3qg1wmsvrLS2fhLU5vNuJNYccUcVcFsZpQZyNXg7utnsHpuwYNvEscii_Q9TEMxOAUTfN5yb1o5CA8kSr6t5_EptTiKcrrJQpZmdG-7EarrrS3jKjRbo7tQ6JRQc5uJJMhMjaVEK5bjEneipPaaQRwnwh884jlFZbVta0hXbvbzgnMBf5kUG5vtbNNWgk49bSHvpFrQU-9CUEZJB9sOAimwaFJZkZ1oZOEaW0HW2_okn0Ff1mM0gobi1BVW1KAS6wF&amp;p=1&amp;fvj=1&amp;vjs=3" id="sja1" onclick="setRefineByCookie(['radius', 'explvl']); sjoc('sja1', 0); convCtr('SJ'); rclk(this,jobmap[1],true,0);" onmousedown="sjomd('sja1'); clk('sja1'); rclk(this,jobmap[1],0);" rel="noopener nofollow" target="_blank" title="Director of Medical Records">
# Director of Medical Records</a>
# Director of Medical Records
# https://www.indeed.com/jobs?q=healthcare&l=Sacramento&radius=15&explvl=entry_level/pagead/clk?mo=r&ad=-6NYlbfkN0B8NV38KXLisi_yba08IRslyje1q7o304qlbxR_KnihTVM3FzL_q2U8AxJnHI-_Zx3ffuTXWJ4Ht2__yh7O-lK7qtY--p7xioClx6MtJZSVcU-fXvM9fZpnhFFJX-VjiEVvx37ZKhBjJtHZhHAMQxGzh8tbH9jYY-Ocuu7_pkl6xd1GYKmjZ8MZFDwACPsB4rRQTr-nWmhkSvvmct9HIg3qg1wmsvrLS2fhLU5vNuJNYccUcVcFsZpQZyNXg7utnsHpuwYNvEscii_Q9TEMxOAUTfN5yb1o5CA8kSr6t5_EptTiKcrrJQpZmdG-7EarrrS3jKjRbo7tQ6JRQc5uJJMhMjaVEK5bjEneipPaaQRwnwh884jlFZbVta0hXbvbzgnMBf5kUG5vtbNNWgk49bSHvpFrQU-9CUEZJB9sOAimwaFJZkZ1oZOEaW0HW2_okn0Ff1mM0gobi1BVW1KAS6wF&p=1&fvj=1&vjs=3
# ['We offer full-time positions and benefits such as: medical, dental, vision, life insurance, supplemental and 401(k) with a company match.', 'Coordinate with IT managers, technicians, developers and other contractors to guide the delivery of new systems.\nKnowledge of project management principles.', 'Open to applicants who do not have a high school diploma/GED.\nOpen to applicants who do not have a college diploma.\nRelays necessary messages to staff.', 'Answer phones, scheduling appointments, billing, basic computer work.\nWe are utilizing all safety measures including a plastic protector at the front desk;…', 'Position includes reception, registration, telephones, medical records, and patient scheduling.\nExperience preferred in medical front office.', 'Medical Scribe needed for a busy OB/GYN office to work closely with physician , will be responsible for but not limited to, real time charting, retrieving…', 'Competency in HR Policies including knowledge with CMS, DHS, and OSHA surveys is a huge plus and previous experience working at an administrative or supervisory…', 'High school diploma or GED.\nThe Admissions Coordinator will treat each resident fairly, kindly, and show them dignity and respect.', 'Responsible for editing/correcting previously signed out cases (Amendments), creating and formatting addendums for signed out cases, and preparing cases for…', 'Respond to high volume inbound calls while compassionately handling questions/concerns.\nHigh school or equivalent (Preferred).', 'High School Graduate, GED or an equivalent combination of education and experience, plus successful completion of medical terminology course is required.', 'As changes in federal law, state law and University policy occur from time to time, The Administrator monitors contracts to ensure continued compliance.', '2 years’ recent experience providing customer service in an administrative capacity- multiline phone, vendor communication, ordering office supplies, filing and…', 'Hours will be approximately 20-30 hours a week, but could increase.\nDuties would include anything from cleaning, assisting with elderly grandfather, casting…', 'High school graduate with diploma or equivalent.\nOne year customer service experience within a call center or with related heavy customer contact experience (i…']
# <a class="jobtitle turnstileLink" data-tn-element="jobTitle" href="/pagead/clk?mo=r&amp;ad=-6NYlbfkN0DE9-0HBpkbX2T54m14AJ4xHatK972OxNX93gAdIbJTD1fCEjOHqTLn0JpMH9ZqbPZwXQjAEJVLssKIjANuN4DHRlIYSw_rW-IVX4fu8GQfMiaFGLiLIZzphlYe8GkHM7Z6zJxiglCQA6jrHwMQnH0adDbmJytj1muV5zP0ma_whmUwvu7hU7TiJ2IVffIXcCFGvu4KOjZqReR04n_n6KxDNc0hJ-hXRZk4n1pupnALsIbKKMwWVZ3M1til5bAUqYqIxJgUVvRx0LGhXNI-qEdw3H-h2_LECNNQ2RMJpW5XzWfrTOnW2Sx1WOP7jGsSqA1In5I6wO9q_MnUAJWCJbErCXVX9T2idmAEd-9K9zxPsNqAd7RdVbusPcYHcHIls0sVMR9rb6n-IKsNvCDMFyaeRSIqLGWMCb-by_ril_MhccbqS3fp4I-LDy3KknhjdrGRtm_OCn8uqg==&amp;p=2&amp;fvj=1&amp;vjs=3" id="sja2" onclick="setRefineByCookie(['radius', 'explvl']); sjoc('sja2', 0); convCtr('SJ'); rclk(this,jobmap[2],true,0);" onmousedown="sjomd('sja2'); clk('sja2'); rclk(this,jobmap[2],0);" rel="noopener nofollow" target="_blank" title="Medical Scheduler">
# Medical Scheduler</a>
# Medical Scheduler
# https://www.indeed.com/jobs?q=healthcare&l=Sacramento&radius=15&explvl=entry_level/pagead/clk?mo=r&ad=-6NYlbfkN0DE9-0HBpkbX2T54m14AJ4xHatK972OxNX93gAdIbJTD1fCEjOHqTLn0JpMH9ZqbPZwXQjAEJVLssKIjANuN4DHRlIYSw_rW-IVX4fu8GQfMiaFGLiLIZzphlYe8GkHM7Z6zJxiglCQA6jrHwMQnH0adDbmJytj1muV5zP0ma_whmUwvu7hU7TiJ2IVffIXcCFGvu4KOjZqReR04n_n6KxDNc0hJ-hXRZk4n1pupnALsIbKKMwWVZ3M1til5bAUqYqIxJgUVvRx0LGhXNI-qEdw3H-h2_LECNNQ2RMJpW5XzWfrTOnW2Sx1WOP7jGsSqA1In5I6wO9q_MnUAJWCJbErCXVX9T2idmAEd-9K9zxPsNqAd7RdVbusPcYHcHIls0sVMR9rb6n-IKsNvCDMFyaeRSIqLGWMCb-by_ril_MhccbqS3fp4I-LDy3KknhjdrGRtm_OCn8uqg==&p=2&fvj=1&vjs=3
# ['We offer full-time positions and benefits such as: medical, dental, vision, life insurance, supplemental and 401(k) with a company match.', 'Coordinate with IT managers, technicians, developers and other contractors to guide the delivery of new systems.\nKnowledge of project management principles.', 'Open to applicants who do not have a high school diploma/GED.\nOpen to applicants who do not have a college diploma.\nRelays necessary messages to staff.', 'Answer phones, scheduling appointments, billing, basic computer work.\nWe are utilizing all safety measures including a plastic protector at the front desk;…', 'Position includes reception, registration, telephones, medical records, and patient scheduling.\nExperience preferred in medical front office.', 'Medical Scribe needed for a busy OB/GYN office to work closely with physician , will be responsible for but not limited to, real time charting, retrieving…', 'Competency in HR Policies including knowledge with CMS, DHS, and OSHA surveys is a huge plus and previous experience working at an administrative or supervisory…', 'High school diploma or GED.\nThe Admissions Coordinator will treat each resident fairly, kindly, and show them dignity and respect.', 'Responsible for editing/correcting previously signed out cases (Amendments), creating and formatting addendums for signed out cases, and preparing cases for…', 'Respond to high volume inbound calls while compassionately handling questions/concerns.\nHigh school or equivalent (Preferred).', 'High School Graduate, GED or an equivalent combination of education and experience, plus successful completion of medical terminology course is required.', 'As changes in federal law, state law and University policy occur from time to time, The Administrator monitors contracts to ensure continued compliance.', '2 years’ recent experience providing customer service in an administrative capacity- multiline phone, vendor communication, ordering office supplies, filing and…', 'Hours will be approximately 20-30 hours a week, but could increase.\nDuties would include anything from cleaning, assisting with elderly grandfather, casting…', 'High school graduate with diploma or equivalent.\nOne year customer service experience within a call center or with related heavy customer contact experience (i…']
# <a class="jobtitle turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=f39fa1f5658f8317&amp;fccid=f2bbc2a882eaed7c&amp;vjs=3" id="jl_f39fa1f5658f8317" onclick="setRefineByCookie(['radius', 'explvl']); return rclk(this,jobmap[3],true,1);" onmousedown="return rclk(this,jobmap[3],1);" rel="noopener nofollow" target="_blank" title="Administrative Assistant II">
# Administrative Assistant II</a>
# Administrative Assistant II
# https://www.indeed.com/jobs?q=healthcare&l=Sacramento&radius=15&explvl=entry_level/rc/clk?jk=f39fa1f5658f8317&fccid=f2bbc2a882eaed7c&vjs=3
# ['We offer full-time positions and benefits such as: medical, dental, vision, life insurance, supplemental and 401(k) with a company match.', 'Coordinate with IT managers, technicians, developers and other contractors to guide the delivery of new systems.\nKnowledge of project management principles.', 'Open to applicants who do not have a high school diploma/GED.\nOpen to applicants who do not have a college diploma.\nRelays necessary messages to staff.', 'Answer phones, scheduling appointments, billing, basic computer work.\nWe are utilizing all safety measures including a plastic protector at the front desk;…', 'Position includes reception, registration, telephones, medical records, and patient scheduling.\nExperience preferred in medical front office.', 'Medical Scribe needed for a busy OB/GYN office to work closely with physician , will be responsible for but not limited to, real time charting, retrieving…', 'Competency in HR Policies including knowledge with CMS, DHS, and OSHA surveys is a huge plus and previous experience working at an administrative or supervisory…', 'High school diploma or GED.\nThe Admissions Coordinator will treat each resident fairly, kindly, and show them dignity and respect.', 'Responsible for editing/correcting previously signed out cases (Amendments), creating and formatting addendums for signed out cases, and preparing cases for…', 'Respond to high volume inbound calls while compassionately handling questions/concerns.\nHigh school or equivalent (Preferred).', 'High School Graduate, GED or an equivalent combination of education and experience, plus successful completion of medical terminology course is required.', 'As changes in federal law, state law and University policy occur from time to time, The Administrator monitors contracts to ensure continued compliance.', '2 years’ recent experience providing customer service in an administrative capacity- multiline phone, vendor communication, ordering office supplies, filing and…', 'Hours will be approximately 20-30 hours a week, but could increase.\nDuties would include anything from cleaning, assisting with elderly grandfather, casting…', 'High school graduate with diploma or equivalent.\nOne year customer service experience within a call center or with related heavy customer contact experience (i…']
# <a class="jobtitle turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=31b62381b5555688&amp;fccid=2ec9e0488117aa05&amp;vjs=3" id="jl_31b62381b5555688" onclick="setRefineByCookie(['radius', 'explvl']); return rclk(this,jobmap[4],true,0);" onmousedown="return rclk(this,jobmap[4],0);" rel="noopener nofollow" target="_blank" title="Unit Secretary - NICU">
# Unit Secretary - NICU</a>
# Unit Secretary - NICU
# https://www.indeed.com/jobs?q=healthcare&l=Sacramento&radius=15&explvl=entry_level/rc/clk?jk=31b62381b5555688&fccid=2ec9e0488117aa05&vjs=3
# ['We offer full-time positions and benefits such as: medical, dental, vision, life insurance, supplemental and 401(k) with a company match.', 'Coordinate with IT managers, technicians, developers and other contractors to guide the delivery of new systems.\nKnowledge of project management principles.', 'Open to applicants who do not have a high school diploma/GED.\nOpen to applicants who do not have a college diploma.\nRelays necessary messages to staff.', 'Answer phones, scheduling appointments, billing, basic computer work.\nWe are utilizing all safety measures including a plastic protector at the front desk;…', 'Position includes reception, registration, telephones, medical records, and patient scheduling.\nExperience preferred in medical front office.', 'Medical Scribe needed for a busy OB/GYN office to work closely with physician , will be responsible for but not limited to, real time charting, retrieving…', 'Competency in HR Policies including knowledge with CMS, DHS, and OSHA surveys is a huge plus and previous experience working at an administrative or supervisory…', 'High school diploma or GED.\nThe Admissions Coordinator will treat each resident fairly, kindly, and show them dignity and respect.', 'Respond to high volume inbound calls while compassionately handling questions/concerns.\nHigh school or equivalent (Preferred).', 'Responsible for editing/correcting previously signed out cases (Amendments), creating and formatting addendums for signed out cases, and preparing cases for…', 'High School Graduate, GED or an equivalent combination of education and experience, plus successful completion of medical terminology course is required.', 'As changes in federal law, state law and University policy occur from time to time, The Administrator monitors contracts to ensure continued compliance.', '2 years’ recent experience providing customer service in an administrative capacity- multiline phone, vendor communication, ordering office supplies, filing and…', 'Hours will be approximately 20-30 hours a week, but could increase.\nDuties would include anything from cleaning, assisting with elderly grandfather, casting…', 'High school graduate with diploma or equivalent.\nOne year customer service experience within a call center or with related heavy customer contact experience (i…']
# <a class="jobtitle turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=f799eb6fe7af087b&amp;fccid=f2bbc2a882eaed7c&amp;vjs=3" id="jl_f799eb6fe7af087b" onclick="setRefineByCookie(['radius', 'explvl']); return rclk(this,jobmap[5],true,1);" onmousedown="return rclk(this,jobmap[5],1);" rel="noopener nofollow" target="_blank" title="(Healthcare) Contracts Administrator 3">
# (<b>Healthcare</b>) Contracts Administrator 3</a>
# (Healthcare) Contracts Administrator 3
# https://www.indeed.com/jobs?q=healthcare&l=Sacramento&radius=15&explvl=entry_level/rc/clk?jk=f799eb6fe7af087b&fccid=f2bbc2a882eaed7c&vjs=3
# ['We offer full-time positions and benefits such as: medical, dental, vision, life insurance, supplemental and 401(k) with a company match.', 'Coordinate with IT managers, technicians, developers and other contractors to guide the delivery of new systems.\nKnowledge of project management principles.', 'Open to applicants who do not have a high school diploma/GED.\nOpen to applicants who do not have a college diploma.\nRelays necessary messages to staff.', 'Answer phones, scheduling appointments, billing, basic computer work.\nWe are utilizing all safety measures including a plastic protector at the front desk;…', 'Position includes reception, registration, telephones, medical records, and patient scheduling.\nExperience preferred in medical front office.', 'Medical Scribe needed for a busy OB/GYN office to work closely with physician , will be responsible for but not limited to, real time charting, retrieving…', 'This is a full-time position and duties include, but are not limited to, checking patients in and out, obtaining and updating demographic and insurance…', 'Competency in HR Policies including knowledge with CMS, DHS, and OSHA surveys is a huge plus and previous experience working at an administrative or supervisory…', 'High school diploma or GED.\nThe Admissions Coordinator will treat each resident fairly, kindly, and show them dignity and respect.', 'Respond to high volume inbound calls while compassionately handling questions/concerns.\nHigh school or equivalent (Preferred).', 'Responsible for editing/correcting previously signed out cases (Amendments), creating and formatting addendums for signed out cases, and preparing cases for…', 'High School Graduate, GED or an equivalent combination of education and experience, plus successful completion of medical terminology course is required.', 'As changes in federal law, state law and University policy occur from time to time, The Administrator monitors contracts to ensure continued compliance.', '2 years’ recent experience providing customer service in an administrative capacity- multiline phone, vendor communication, ordering office supplies, filing and…', 'Hours will be approximately 20-30 hours a week, but could increase.\nDuties would include anything from cleaning, assisting with elderly grandfather, casting…']
# <a class="jobtitle turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=2f6841a3fe6a17d1&amp;fccid=f2bbc2a882eaed7c&amp;vjs=3" id="jl_2f6841a3fe6a17d1" onclick="setRefineByCookie(['radius', 'explvl']); return rclk(this,jobmap[6],true,1);" onmousedown="return rclk(this,jobmap[6],1);" rel="noopener nofollow" target="_blank" title="Administrative Assistant II-Purchasing">
# Administrative Assistant II-Purchasing</a>
# Administrative Assistant II-Purchasing
# https://www.indeed.com/jobs?q=healthcare&l=Sacramento&radius=15&explvl=entry_level/rc/clk?jk=2f6841a3fe6a17d1&fccid=f2bbc2a882eaed7c&vjs=3
# ['We offer full-time positions and benefits such as: medical, dental, vision, life insurance, supplemental and 401(k) with a company match.', 'Coordinate with IT managers, technicians, developers and other contractors to guide the delivery of new systems.\nKnowledge of project management principles.', 'Open to applicants who do not have a high school diploma/GED.\nOpen to applicants who do not have a college diploma.\nRelays necessary messages to staff.', 'Answer phones, scheduling appointments, billing, basic computer work.\nWe are utilizing all safety measures including a plastic protector at the front desk;…', 'Position includes reception, registration, telephones, medical records, and patient scheduling.\nExperience preferred in medical front office.', 'Medical Scribe needed for a busy OB/GYN office to work closely with physician , will be responsible for but not limited to, real time charting, retrieving…', 'Competency in HR Policies including knowledge with CMS, DHS, and OSHA surveys is a huge plus and previous experience working at an administrative or supervisory…', 'High school diploma or GED.\nThe Admissions Coordinator will treat each resident fairly, kindly, and show them dignity and respect.', 'Responsible for editing/correcting previously signed out cases (Amendments), creating and formatting addendums for signed out cases, and preparing cases for…', 'Respond to high volume inbound calls while compassionately handling questions/concerns.\nHigh school or equivalent (Preferred).', 'High School Graduate, GED or an equivalent combination of education and experience, plus successful completion of medical terminology course is required.', 'As changes in federal law, state law and University policy occur from time to time, The Administrator monitors contracts to ensure continued compliance.', '2 years’ recent experience providing customer service in an administrative capacity- multiline phone, vendor communication, ordering office supplies, filing and…', 'Hours will be approximately 20-30 hours a week, but could increase.\nDuties would include anything from cleaning, assisting with elderly grandfather, casting…', 'High school graduate with diploma or equivalent.\nOne year customer service experience within a call center or with related heavy customer contact experience (i…']
# <a class="jobtitle turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=1dce212f5dedc777&amp;fccid=8b11bd0c33da064e&amp;vjs=3" id="jl_1dce212f5dedc777" onclick="setRefineByCookie(['radius', 'explvl']); return rclk(this,jobmap[7],true,0);" onmousedown="return rclk(this,jobmap[7],0);" rel="noopener nofollow" target="_blank" title="Customer Service Representative I">
# Customer Service Representative I</a>
# Customer Service Representative I
# https://www.indeed.com/jobs?q=healthcare&l=Sacramento&radius=15&explvl=entry_level/rc/clk?jk=1dce212f5dedc777&fccid=8b11bd0c33da064e&vjs=3
# ['We offer full-time positions and benefits such as: medical, dental, vision, life insurance, supplemental and 401(k) with a company match.', 'Coordinate with IT managers, technicians, developers and other contractors to guide the delivery of new systems.\nKnowledge of project management principles.', 'Open to applicants who do not have a high school diploma/GED.\nOpen to applicants who do not have a college diploma.\nRelays necessary messages to staff.', 'Answer phones, scheduling appointments, billing, basic computer work.\nWe are utilizing all safety measures including a plastic protector at the front desk;…', 'Position includes reception, registration, telephones, medical records, and patient scheduling.\nExperience preferred in medical front office.', 'Medical Scribe needed for a busy OB/GYN office to work closely with physician , will be responsible for but not limited to, real time charting, retrieving…', 'Competency in HR Policies including knowledge with CMS, DHS, and OSHA surveys is a huge plus and previous experience working at an administrative or supervisory…', 'High school diploma or GED.\nThe Admissions Coordinator will treat each resident fairly, kindly, and show them dignity and respect.', 'Responsible for editing/correcting previously signed out cases (Amendments), creating and formatting addendums for signed out cases, and preparing cases for…', 'Respond to high volume inbound calls while compassionately handling questions/concerns.\nHigh school or equivalent (Preferred).', 'High School Graduate, GED or an equivalent combination of education and experience, plus successful completion of medical terminology course is required.', 'As changes in federal law, state law and University policy occur from time to time, The Administrator monitors contracts to ensure continued compliance.', '2 years’ recent experience providing customer service in an administrative capacity- multiline phone, vendor communication, ordering office supplies, filing and…', 'Hours will be approximately 20-30 hours a week, but could increase.\nDuties would include anything from cleaning, assisting with elderly grandfather, casting…', 'High school graduate with diploma or equivalent.\nOne year customer service experience within a call center or with related heavy customer contact experience (i…']
# <a class="jobtitle turnstileLink" data-tn-element="jobTitle" href="/company/visit--healthcare/jobs/Certified-Medical-Assistant-bb389293e577a75c?fccid=91bc39b53d4226f3&amp;vjs=3" id="jl_bb389293e577a75c" onclick="setRefineByCookie(['radius', 'explvl']); return rclk(this,jobmap[8],true,1);" onmousedown="return rclk(this,jobmap[8],1);" rel="noopener nofollow" target="_blank" title="Certified Medical Assistants needed ASAP!">
# Certified Medical Assistants needed ASAP!</a>
# Certified Medical Assistants needed ASAP!
# https://www.indeed.com/jobs?q=healthcare&l=Sacramento&radius=15&explvl=entry_level/company/visit--healthcare/jobs/Certified-Medical-Assistant-bb389293e577a75c?fccid=91bc39b53d4226f3&vjs=3
# ['We offer full-time positions and benefits such as: medical, dental, vision, life insurance, supplemental and 401(k) with a company match.', 'Coordinate with IT managers, technicians, developers and other contractors to guide the delivery of new systems.\nKnowledge of project management principles.', 'Open to applicants who do not have a high school diploma/GED.\nOpen to applicants who do not have a college diploma.\nRelays necessary messages to staff.', 'Answer phones, scheduling appointments, billing, basic computer work.\nWe are utilizing all safety measures including a plastic protector at the front desk;…', 'Position includes reception, registration, telephones, medical records, and patient scheduling.\nExperience preferred in medical front office.', 'Medical Scribe needed for a busy OB/GYN office to work closely with physician , will be responsible for but not limited to, real time charting, retrieving…', 'This is a full-time position and duties include, but are not limited to, checking patients in and out, obtaining and updating demographic and insurance…', 'Competency in HR Policies including knowledge with CMS, DHS, and OSHA surveys is a huge plus and previous experience working at an administrative or supervisory…', 'High school diploma or GED.\nThe Admissions Coordinator will treat each resident fairly, kindly, and show them dignity and respect.', 'Responsible for editing/correcting previously signed out cases (Amendments), creating and formatting addendums for signed out cases, and preparing cases for…', 'Respond to high volume inbound calls while compassionately handling questions/concerns.\nHigh school or equivalent (Preferred).', 'High School Graduate, GED or an equivalent combination of education and experience, plus successful completion of medical terminology course is required.', 'As changes in federal law, state law and University policy occur from time to time, The Administrator monitors contracts to ensure continued compliance.', '2 years’ recent experience providing customer service in an administrative capacity- multiline phone, vendor communication, ordering office supplies, filing and…', 'Hours will be approximately 20-30 hours a week, but could increase.\nDuties would include anything from cleaning, assisting with elderly grandfather, casting…']
# <a class="jobtitle turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=47e7d6161d66881f&amp;fccid=2ec9e0488117aa05&amp;vjs=3" id="jl_47e7d6161d66881f" onclick="setRefineByCookie(['radius', 'explvl']); return rclk(this,jobmap[9],true,0);" onmousedown="return rclk(this,jobmap[9],0);" rel="noopener nofollow" target="_blank" title="Patient Services Representative">
# Patient Services Representative</a>
# Patient Services Representative
# https://www.indeed.com/jobs?q=healthcare&l=Sacramento&radius=15&explvl=entry_level/rc/clk?jk=47e7d6161d66881f&fccid=2ec9e0488117aa05&vjs=3
# ['We offer full-time positions and benefits such as: medical, dental, vision, life insurance, supplemental and 401(k) with a company match.', 'Coordinate with IT managers, technicians, developers and other contractors to guide the delivery of new systems.\nKnowledge of project management principles.', 'Open to applicants who do not have a high school diploma/GED.\nOpen to applicants who do not have a college diploma.\nRelays necessary messages to staff.', 'Answer phones, scheduling appointments, billing, basic computer work.\nWe are utilizing all safety measures including a plastic protector at the front desk;…', 'Position includes reception, registration, telephones, medical records, and patient scheduling.\nExperience preferred in medical front office.', 'Medical Scribe needed for a busy OB/GYN office to work closely with physician , will be responsible for but not limited to, real time charting, retrieving…', 'Competency in HR Policies including knowledge with CMS, DHS, and OSHA surveys is a huge plus and previous experience working at an administrative or supervisory…', 'High school diploma or GED.\nThe Admissions Coordinator will treat each resident fairly, kindly, and show them dignity and respect.', 'Respond to high volume inbound calls while compassionately handling questions/concerns.\nHigh school or equivalent (Preferred).', 'Responsible for editing/correcting previously signed out cases (Amendments), creating and formatting addendums for signed out cases, and preparing cases for…', 'High School Graduate, GED or an equivalent combination of education and experience, plus successful completion of medical terminology course is required.', 'As changes in federal law, state law and University policy occur from time to time, The Administrator monitors contracts to ensure continued compliance.', '2 years’ recent experience providing customer service in an administrative capacity- multiline phone, vendor communication, ordering office supplies, filing and…', 'Hours will be approximately 20-30 hours a week, but could increase.\nDuties would include anything from cleaning, assisting with elderly grandfather, casting…', 'High school graduate with diploma or equivalent.\nOne year customer service experience within a call center or with related heavy customer contact experience (i…']
# <a class="jobtitle turnstileLink" data-tn-element="jobTitle" href="/company/Baratta-Holistic-Center/jobs/Chiropractic-Assistant-ae90e7dd204352e6?fccid=a5e6542d2dc247ec&amp;vjs=3" id="jl_ae90e7dd204352e6" onclick="setRefineByCookie(['radius', 'explvl']); return rclk(this,jobmap[10],true,1);" onmousedown="return rclk(this,jobmap[10],1);" rel="noopener nofollow" target="_blank" title="Chiropractic Assistant">
# Chiropractic Assistant</a>
# Chiropractic Assistant
# https://www.indeed.com/jobs?q=healthcare&l=Sacramento&radius=15&explvl=entry_level/company/Baratta-Holistic-Center/jobs/Chiropractic-Assistant-ae90e7dd204352e6?fccid=a5e6542d2dc247ec&vjs=3
# ['We offer full-time positions and benefits such as: medical, dental, vision, life insurance, supplemental and 401(k) with a company match.', 'Coordinate with IT managers, technicians, developers and other contractors to guide the delivery of new systems.\nKnowledge of project management principles.', 'Open to applicants who do not have a high school diploma/GED.\nOpen to applicants who do not have a college diploma.\nRelays necessary messages to staff.', 'Answer phones, scheduling appointments, billing, basic computer work.\nWe are utilizing all safety measures including a plastic protector at the front desk;…', 'Position includes reception, registration, telephones, medical records, and patient scheduling.\nExperience preferred in medical front office.', 'Medical Scribe needed for a busy OB/GYN office to work closely with physician , will be responsible for but not limited to, real time charting, retrieving…', 'Competency in HR Policies including knowledge with CMS, DHS, and OSHA surveys is a huge plus and previous experience working at an administrative or supervisory…', 'High school diploma or GED.\nThe Admissions Coordinator will treat each resident fairly, kindly, and show them dignity and respect.', 'Responsible for editing/correcting previously signed out cases (Amendments), creating and formatting addendums for signed out cases, and preparing cases for…', 'Respond to high volume inbound calls while compassionately handling questions/concerns.\nHigh school or equivalent (Preferred).', 'High School Graduate, GED or an equivalent combination of education and experience, plus successful completion of medical terminology course is required.', 'As changes in federal law, state law and University policy occur from time to time, The Administrator monitors contracts to ensure continued compliance.', '2 years’ recent experience providing customer service in an administrative capacity- multiline phone, vendor communication, ordering office supplies, filing and…', 'Hours will be approximately 20-30 hours a week, but could increase.\nDuties would include anything from cleaning, assisting with elderly grandfather, casting…', 'High school graduate with diploma or equivalent.\nOne year customer service experience within a call center or with related heavy customer contact experience (i…']
# <a class="jobtitle turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=17512b0101b46db7&amp;fccid=e547a53fee71ca6c&amp;vjs=3" id="jl_17512b0101b46db7" onclick="setRefineByCookie(['radius', 'explvl']); return rclk(this,jobmap[11],true,0);" onmousedown="return rclk(this,jobmap[11],0);" rel="noopener nofollow" target="_blank" title="Receptionist">
# Receptionist</a>
# Receptionist
# https://www.indeed.com/jobs?q=healthcare&l=Sacramento&radius=15&explvl=entry_level/rc/clk?jk=17512b0101b46db7&fccid=e547a53fee71ca6c&vjs=3
# ['We offer full-time positions and benefits such as: medical, dental, vision, life insurance, supplemental and 401(k) with a company match.', 'Coordinate with IT managers, technicians, developers and other contractors to guide the delivery of new systems.\nKnowledge of project management principles.', 'Open to applicants who do not have a high school diploma/GED.\nOpen to applicants who do not have a college diploma.\nRelays necessary messages to staff.', 'Answer phones, scheduling appointments, billing, basic computer work.\nWe are utilizing all safety measures including a plastic protector at the front desk;…', 'Position includes reception, registration, telephones, medical records, and patient scheduling.\nExperience preferred in medical front office.', 'Medical Scribe needed for a busy OB/GYN office to work closely with physician , will be responsible for but not limited to, real time charting, retrieving…', 'Competency in HR Policies including knowledge with CMS, DHS, and OSHA surveys is a huge plus and previous experience working at an administrative or supervisory…', 'High school diploma or GED.\nThe Admissions Coordinator will treat each resident fairly, kindly, and show them dignity and respect.', 'Responsible for editing/correcting previously signed out cases (Amendments), creating and formatting addendums for signed out cases, and preparing cases for…', 'Respond to high volume inbound calls while compassionately handling questions/concerns.\nHigh school or equivalent (Preferred).', 'High School Graduate, GED or an equivalent combination of education and experience, plus successful completion of medical terminology course is required.', 'As changes in federal law, state law and University policy occur from time to time, The Administrator monitors contracts to ensure continued compliance.', '2 years’ recent experience providing customer service in an administrative capacity- multiline phone, vendor communication, ordering office supplies, filing and…', 'Hours will be approximately 20-30 hours a week, but could increase.\nDuties would include anything from cleaning, assisting with elderly grandfather, casting…', 'High school graduate with diploma or equivalent.\nOne year customer service experience within a call center or with related heavy customer contact experience (i…']
# <a class="jobtitle turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=48922017a74dc125&amp;fccid=e309b8a71206cc5c&amp;vjs=3" id="jl_48922017a74dc125" onclick="setRefineByCookie(['radius', 'explvl']); return rclk(this,jobmap[12],true,0);" onmousedown="return rclk(this,jobmap[12],0);" rel="noopener nofollow" target="_blank" title="Surgery Scheduling Clerk-R">
# Surgery Scheduling Clerk-R</a>
# Surgery Scheduling Clerk-R
# https://www.indeed.com/jobs?q=healthcare&l=Sacramento&radius=15&explvl=entry_level/rc/clk?jk=48922017a74dc125&fccid=e309b8a71206cc5c&vjs=3
# ['We offer full-time positions and benefits such as: medical, dental, vision, life insurance, supplemental and 401(k) with a company match.', 'Coordinate with IT managers, technicians, developers and other contractors to guide the delivery of new systems.\nKnowledge of project management principles.', 'Open to applicants who do not have a high school diploma/GED.\nOpen to applicants who do not have a college diploma.\nRelays necessary messages to staff.', 'Answer phones, scheduling appointments, billing, basic computer work.\nWe are utilizing all safety measures including a plastic protector at the front desk;…', 'Position includes reception, registration, telephones, medical records, and patient scheduling.\nExperience preferred in medical front office.', 'Medical Scribe needed for a busy OB/GYN office to work closely with physician , will be responsible for but not limited to, real time charting, retrieving…', 'Competency in HR Policies including knowledge with CMS, DHS, and OSHA surveys is a huge plus and previous experience working at an administrative or supervisory…', 'High school diploma or GED.\nThe Admissions Coordinator will treat each resident fairly, kindly, and show them dignity and respect.', 'Respond to high volume inbound calls while compassionately handling questions/concerns.\nHigh school or equivalent (Preferred).', 'Responsible for editing/correcting previously signed out cases (Amendments), creating and formatting addendums for signed out cases, and preparing cases for…', 'High School Graduate, GED or an equivalent combination of education and experience, plus successful completion of medical terminology course is required.', 'As changes in federal law, state law and University policy occur from time to time, The Administrator monitors contracts to ensure continued compliance.', '2 years’ recent experience providing customer service in an administrative capacity- multiline phone, vendor communication, ordering office supplies, filing and…', 'Hours will be approximately 20-30 hours a week, but could increase.\nDuties would include anything from cleaning, assisting with elderly grandfather, casting…', 'High school graduate with diploma or equivalent.\nOne year customer service experience within a call center or with related heavy customer contact experience (i…']
# <a class="jobtitle turnstileLink" data-tn-element="jobTitle" href="/pagead/clk?mo=r&amp;ad=-6NYlbfkN0B6DFt42r_7h6gtRxyXFWHZy9SnEKO30TWlID7d3UEI0Hf56pDDxvmC57JaU2RLcYmJi9kzDp2l0gZ6C2fD9iV6Wey_wRTRcHVJZUKGwRGrRiMmSwSWB_ZlOKCQizfyTCRF4Kx-lpRHgmEPJXFj7lzAn5vDDu72UBzKv4gwV-YGyfiQp9QqBT8ThicF-CnFXvCIr7UWrPv_ZSiW8vsbly533L3s69ZLVe8PhfRfk4Pv9ZCnoqo1oc6kiafiD-8K-3ictdsIWvFmtOb8hDCBiOJDt8EkdrZLf7W7Hd5mQb3b9kC-Fwrmev_fpPkJnHJiNd1nqGAKB7-wnypbugNt2ZoibbdgqW7tO6BGEvRWorJBQ-15w-sVSNkcEm7PFJwUgtOSt9HnRCYQQmf4JUNMt78FyzzLlZaZ4Y3FFMH1XtnLPVD2djabtk5KeCI_s4za7Pl0i_eQnJjRBHUmQBMQCIm80s0awx9LwY7mkvmEkGncxnHF8RZHZd6wN6rOSxOebJOaA7z_Bet0B852psOkpiEz4mgQ2Sqlk-qBz8d4FjhvzNadX4fPscGH9EOcQSm6LgdJmAHYpvPfjbY-MUlHo-70m0QPV1JWlxdiv6uGLjxjqBvUhgZkFoe8Ruiru76h6qo=&amp;p=13&amp;fvj=0&amp;vjs=3" id="sja13" onclick="setRefineByCookie(['radius', 'explvl']); sjoc('sja13', 1); convCtr('SJ'); rclk(this,jobmap[13],true,1);" onmousedown="sjomd('sja13'); clk('sja13'); rclk(this,jobmap[13],1);" rel="noopener nofollow" target="_blank" title="Ambulatory Surgery Center Administrator">
# Ambulatory Surgery Center Administrator</a>
# Ambulatory Surgery Center Administrator
# https://www.indeed.com/jobs?q=healthcare&l=Sacramento&radius=15&explvl=entry_level/pagead/clk?mo=r&ad=-6NYlbfkN0B6DFt42r_7h6gtRxyXFWHZy9SnEKO30TWlID7d3UEI0Hf56pDDxvmC57JaU2RLcYmJi9kzDp2l0gZ6C2fD9iV6Wey_wRTRcHVJZUKGwRGrRiMmSwSWB_ZlOKCQizfyTCRF4Kx-lpRHgmEPJXFj7lzAn5vDDu72UBzKv4gwV-YGyfiQp9QqBT8ThicF-CnFXvCIr7UWrPv_ZSiW8vsbly533L3s69ZLVe8PhfRfk4Pv9ZCnoqo1oc6kiafiD-8K-3ictdsIWvFmtOb8hDCBiOJDt8EkdrZLf7W7Hd5mQb3b9kC-Fwrmev_fpPkJnHJiNd1nqGAKB7-wnypbugNt2ZoibbdgqW7tO6BGEvRWorJBQ-15w-sVSNkcEm7PFJwUgtOSt9HnRCYQQmf4JUNMt78FyzzLlZaZ4Y3FFMH1XtnLPVD2djabtk5KeCI_s4za7Pl0i_eQnJjRBHUmQBMQCIm80s0awx9LwY7mkvmEkGncxnHF8RZHZd6wN6rOSxOebJOaA7z_Bet0B852psOkpiEz4mgQ2Sqlk-qBz8d4FjhvzNadX4fPscGH9EOcQSm6LgdJmAHYpvPfjbY-MUlHo-70m0QPV1JWlxdiv6uGLjxjqBvUhgZkFoe8Ruiru76h6qo=&p=13&fvj=0&vjs=3
# ['We offer full-time positions and benefits such as: medical, dental, vision, life insurance, supplemental and 401(k) with a company match.', 'Coordinate with IT managers, technicians, developers and other contractors to guide the delivery of new systems.\nKnowledge of project management principles.', 'Open to applicants who do not have a high school diploma/GED.\nOpen to applicants who do not have a college diploma.\nRelays necessary messages to staff.', 'Answer phones, scheduling appointments, billing, basic computer work.\nWe are utilizing all safety measures including a plastic protector at the front desk;…', 'Position includes reception, registration, telephones, medical records, and patient scheduling.\nExperience preferred in medical front office.', 'Medical Scribe needed for a busy OB/GYN office to work closely with physician , will be responsible for but not limited to, real time charting, retrieving…', 'Competency in HR Policies including knowledge with CMS, DHS, and OSHA surveys is a huge plus and previous experience working at an administrative or supervisory…', 'High school diploma or GED.\nThe Admissions Coordinator will treat each resident fairly, kindly, and show them dignity and respect.', 'Responsible for editing/correcting previously signed out cases (Amendments), creating and formatting addendums for signed out cases, and preparing cases for…', 'Respond to high volume inbound calls while compassionately handling questions/concerns.\nHigh school or equivalent (Preferred).', 'High School Graduate, GED or an equivalent combination of education and experience, plus successful completion of medical terminology course is required.', 'As changes in federal law, state law and University policy occur from time to time, The Administrator monitors contracts to ensure continued compliance.', '2 years’ recent experience providing customer service in an administrative capacity- multiline phone, vendor communication, ordering office supplies, filing and…', 'Hours will be approximately 20-30 hours a week, but could increase.\nDuties would include anything from cleaning, assisting with elderly grandfather, casting…', 'High school graduate with diploma or equivalent.\nOne year customer service experience within a call center or with related heavy customer contact experience (i…']
# <a class="jobtitle turnstileLink" data-tn-element="jobTitle" href="/pagead/clk?mo=r&amp;ad=-6NYlbfkN0BAHJu3odRN9xQxFEfA8yuRD6WUpiIEPi5e41I7FRiweeSa9_lgDepKP5J99EGXJftXyDS0-qfhFXrjehyoCtchxeaJF0wPEHvZuBs3KxQ17-2mMNM91IOjuZZgPHgduY8K6co7nIm6_kswakALnMnvB3BfqOqnyS6pPgHEMtx5zBvHH9bFWqkDWY9EQgvomgJUnNpDiV12pJFhuQUgRycc1wcWeol54pb_TAyyzLeAf1mF-t7uRgMB3HWYzqWyrgpa4EC3cDq1p72-rD3HOB_Kx542-rK2sX3UOkhrsLHvEod9lk39tZQQX-XHevcWy4ctnVu16EqifkyyLSjmkogsQjlXfJaONgdg4ZKUa1P01Kzsyrj1G7eRilifTR1fVDWHYW4EOOi0Tu-Dt5HqbCmCH8F6NMHA8qrqdxRw55h0i1QE2Gv_8OQ_ML_lksdSStI=&amp;p=14&amp;fvj=1&amp;vjs=3" id="sja14" onclick="setRefineByCookie(['radius', 'explvl']); sjoc('sja14', 1); convCtr('SJ'); rclk(this,jobmap[14],true,1);" onmousedown="sjomd('sja14'); clk('sja14'); rclk(this,jobmap[14],1);" rel="noopener nofollow" target="_blank" title="Medical Scribe">
# Medical Scribe</a>
# Medical Scribe
# https://www.indeed.com/jobs?q=healthcare&l=Sacramento&radius=15&explvl=entry_level/pagead/clk?mo=r&ad=-6NYlbfkN0BAHJu3odRN9xQxFEfA8yuRD6WUpiIEPi5e41I7FRiweeSa9_lgDepKP5J99EGXJftXyDS0-qfhFXrjehyoCtchxeaJF0wPEHvZuBs3KxQ17-2mMNM91IOjuZZgPHgduY8K6co7nIm6_kswakALnMnvB3BfqOqnyS6pPgHEMtx5zBvHH9bFWqkDWY9EQgvomgJUnNpDiV12pJFhuQUgRycc1wcWeol54pb_TAyyzLeAf1mF-t7uRgMB3HWYzqWyrgpa4EC3cDq1p72-rD3HOB_Kx542-rK2sX3UOkhrsLHvEod9lk39tZQQX-XHevcWy4ctnVu16EqifkyyLSjmkogsQjlXfJaONgdg4ZKUa1P01Kzsyrj1G7eRilifTR1fVDWHYW4EOOi0Tu-Dt5HqbCmCH8F6NMHA8qrqdxRw55h0i1QE2Gv_8OQ_ML_lksdSStI=&p=14&fvj=1&vjs=3
# ['We offer full-time positions and benefits such as: medical, dental, vision, life insurance, supplemental and 401(k) with a company match.', 'Coordinate with IT managers, technicians, developers and other contractors to guide the delivery of new systems.\nKnowledge of project management principles.', 'Open to applicants who do not have a high school diploma/GED.\nOpen to applicants who do not have a college diploma.\nRelays necessary messages to staff.', 'Answer phones, scheduling appointments, billing, basic computer work.\nWe are utilizing all safety measures including a plastic protector at the front desk;…', 'Position includes reception, registration, telephones, medical records, and patient scheduling.\nExperience preferred in medical front office.', 'Medical Scribe needed for a busy OB/GYN office to work closely with physician , will be responsible for but not limited to, real time charting, retrieving…', 'Competency in HR Policies including knowledge with CMS, DHS, and OSHA surveys is a huge plus and previous experience working at an administrative or supervisory…', 'High school diploma or GED.\nThe Admissions Coordinator will treat each resident fairly, kindly, and show them dignity and respect.', 'Responsible for editing/correcting previously signed out cases (Amendments), creating and formatting addendums for signed out cases, and preparing cases for…', 'Respond to high volume inbound calls while compassionately handling questions/concerns.\nHigh school or equivalent (Preferred).', 'High School Graduate, GED or an equivalent combination of education and experience, plus successful completion of medical terminology course is required.', 'As changes in federal law, state law and University policy occur from time to time, The Administrator monitors contracts to ensure continued compliance.', '2 years’ recent experience providing customer service in an administrative capacity- multiline phone, vendor communication, ordering office supplies, filing and…', 'Hours will be approximately 20-30 hours a week, but could increase.\nDuties would include anything from cleaning, assisting with elderly grandfather, casting…', 'High school graduate with diploma or equivalent.\nOne year customer service experience within a call center or with related heavy customer contact experience (i…']
# []

# %% [markdown]
# # Run Full Scrape

# %%
max_results_per_industry = 100
columns = ['industry', 'job_title', 'company_name', 'location', 'summary', 'date_posted']
industry_set = ['healthcare', 'education', 'teaching', 'construction', 'services', 'hospitality', 'technology']
scrape_df = pd.DataFrame(columns = columns)

# %%
#scraping code:
for industry in industry_set:
    
    for start in range(0, max_results_per_industry, 10):
        
        url = '{base_url}jobs?q={industry}&l={city}&radius={distance}&explvl={level}&start={start}'.format(base_url=BASE_URL, city=CITY, industry=industry, distance=MAX_DISTANCE_KM, level=LEVEL, start=start)
        page = requests.get(url)
        
        time.sleep(1)  #ensuring at least 1 second between page grabs
        soup = BeautifulSoup(page.text, features='html.parser', from_encoding='utf-8')
        count=0
        for div in soup.find_all(name='div', attrs={'class':'row'}): 
            #specifying row num for index of job posting in dataframe
            num = (len(scrape_df) + 1) 

            #creating an empty list to hold the data for each posting
            job_post = [] 
            job_post.append(industry) 

            #grabbing job title
            for a in div.find_all(name='a', attrs={'data-tn-element':'jobTitle'}):
                job_post.append(a['title']) 
            if len(job_post) < 2:
                job_post.append('N/A')

            #grabbing company name
            company = div.find_all(name='span', attrs={'class':'company'}) 
            if len(company) > 0: 
                for b in company:
                    job_post.append(b.text.strip()) 
            
            else: 
                sec_try = div.find_all(name='span', attrs={'class':'result-link-source'})
                for span in sec_try:
                    job_post.append(span.text)
            if len(job_post) < 3:
                job_post.append('N/A')

            #grabbing location name
            c = div.findAll('div', attrs={'class': 'location'}) 
            for div in c: 
                job_post.append(div.text)
            if len(job_post) < 4:
                job_post.append('N/A')

            #grabbing summary text
            div = soup.findAll('div', attrs={'class': 'summary'})[count]
            job_post.append(div.text.strip())
            if len(job_post) < 5:
                job_post.append('N/A')
                
            #grabbing date posted
            span = soup.findAll('span', attrs={'class': 'date'})[count]
            job_post.append(span.text)
            if len(job_post) < 6:
                job_post.append('N/A')

            count +=1
            
            #appending list of job post info to dataframe at index num
            if len(job_post) == 6:
                scrape_df.loc[num] = job_post
            else:
                print(job_post)


#saving scrape_df as a local csv file — define your own local path to save contents 
scrape_df.to_csv('indeed_scrape.csv', encoding='utf-8')

# %%
scrape_df
# Out:
#         industry                                          job_title  \
# 1     healthcare                                  Medical Scheduler
# 2     healthcare                             Chiropractic Assistant
# 3     healthcare  Administrative Assistant for Medical Front Office
# 4     healthcare                                     Medical Scribe
# 5     healthcare                                  Surgery Scheduler
# ...          ...                                                ...
# 1051  technology                            Cloud Security Engineer
# 1052  technology                                   Jenkins Engineer
# 1053  technology                                GCP DevOps Engineer
# 1054  technology  ESRI GIS SOLUTIONS ARCHITECT -Sacramento, CA-C...
# 1055  technology                                    Splunk Engineer
#
#                                     company_name  \
# 1                Sacramento Ear, Nose and Throat
# 2                        Baratta Holistic Center
# 3                California IVF Fertility Center
# 4                           Capital OB/GYN, Inc.
# 5     Northern California Orthopaedic Associates
# ...                                          ...
# 1051                                     Cotocus
# 1052                                     Cotocus
# 1053                                     Cotocus
# 1054                              ASAP Solutions
# 1055                                     Cotocus
#
#                                                location  \
# 1     Sacramento, CA 95815 (Johnson Business Park area)
# 2                                  Carmichael, CA 95608
# 3            Sacramento, CA 95833 (Gateway Center area)
# 4            Sacramento, CA 95825 (Campus Commons area)
# 5               Sacramento, CA 95825 (Sierra Oaks area)
# ...                                                 ...
# 1051                                                N/A
# 1052                                                N/A
# 1053                                                N/A
# 1054                                                N/A
# 1055                                                N/A
#
#                                                 summary   date_posted
# 1     Open to applicants who do not have a high scho...   22 days ago
# 2     Answer phones, scheduling appointments, billin...    6 days ago
# 3     Position includes reception, registration, tel...  30+ days ago
# 4     Medical Scribe needed for a busy OB/GYN office...   19 days ago
# 5     High school or equivalent (Preferred).\nPrevio...  30+ days ago
# ...                                                 ...           ...
# 1051  The cloud security engineer specializes in pro...  30+ days ago
# 1052  You should have in-depth knowledge of at least...  30+ days ago
# 1053  GCP DevOps Engineer is accountable for efficie...  30+ days ago
# 1054  Experience working with ESRI Enterprise soluti...  30+ days ago
# 1055  Familiarity with Phantom, Cloud computing, Web...  30+ days ago
#
# [1055 rows x 6 columns]
